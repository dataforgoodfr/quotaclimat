# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

repo_root_path = os.path.abspath(os.path.join("..", "..", ".."))

if repo_root_path not in sys.path:
    sys.path.append(repo_root_path)

# %%
from datetime import datetime
from zoneinfo import ZoneInfo
from analyse.advertising.e01_rupture_detection.split_chunks import (
    split_week_in_segments,
)

tz_paris = ZoneInfo("Europe/Paris")
channel = "tf1"

MONDAY_LAST_YEAR = datetime(2025, 3, 10, tzinfo=tz_paris)

# %%
SEGMENTS_FOLDER = os.path.join("../working_data", f"segments_{channel}_{MONDAY_LAST_YEAR.strftime('%Y%m%d')}")

if not os.path.exists(SEGMENTS_FOLDER):
    os.makedirs(SEGMENTS_FOLDER)
    print(f"Created folder for new extraction: {SEGMENTS_FOLDER}")

await split_week_in_segments(channel, MONDAY_LAST_YEAR, SEGMENTS_FOLDER)
# Out:
# Created folder for new extraction: ../working_data/segments_tf1_20250310
# [1/5] Chargement : ../exports/tf1_2025-03-09_23-00-00Z_2025-03-09_23-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 5.56s
# [2/5] Extraction des features...
#       → 4.00s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00469 (percentile 8.0) → 9452 frames silencieuses (11.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.75s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0034 (percentile 90)
#       Après seuil + distance min (1.0s) : 216 ruptures candidates
#       Résultat final : 216 ruptures → 217 segments
#       → 0.00s
# [5/5] Segmentation terminée : 217 segments  → 0.01s
#       Durée totale : 11.31s
# [1/5] Chargement : ../exports/tf1_2025-03-09_23-30-00Z_2025-03-10_00-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 3.91s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.01127 (percentile 8.0) → 10259 frames silencieuses (12.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0047 (percentile 90)
#       Après seuil + distance min (1.0s) : 229 ruptures candidates
#       Résultat final : 229 ruptures → 230 segments
#       → 0.00s
# [5/5] Segmentation terminée : 230 segments  → 0.01s
#       Durée totale : 9.87s
# [1/5] Chargement : ../exports/tf1_2025-03-10_00-00-00Z_2025-03-10_00-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00675 (percentile 8.0) → 9416 frames silencieuses (11.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0040 (percentile 90)
#       Après seuil + distance min (1.0s) : 238 ruptures candidates
#       Résultat final : 238 ruptures → 239 segments
#       → 0.00s
# [5/5] Segmentation terminée : 239 segments  → 0.01s
#       Durée totale : 9.88s
# [1/5] Chargement : ../exports/tf1_2025-03-10_00-30-00Z_2025-03-10_01-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 4.00s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00792 (percentile 8.0) → 11480 frames silencieuses (14.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.72s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0076 (percentile 90)
#       Après seuil + distance min (1.0s) : 294 ruptures candidates
#       Résultat final : 294 ruptures → 295 segments
#       → 0.00s
# [5/5] Segmentation terminée : 295 segments  → 0.01s
#       Durée totale : 10.01s
# [1/5] Chargement : ../exports/tf1_2025-03-10_01-00-00Z_2025-03-10_01-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 4.05s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00532 (percentile 8.0) → 10582 frames silencieuses (13.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.72s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0062 (percentile 90)
#       Après seuil + distance min (1.0s) : 264 ruptures candidates
#       Résultat final : 264 ruptures → 265 segments
#       → 0.00s
# [5/5] Segmentation terminée : 265 segments  → 0.01s
#       Durée totale : 10.12s
# [1/5] Chargement : ../exports/tf1_2025-03-10_01-30-00Z_2025-03-10_02-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.08s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00539 (percentile 8.0) → 10860 frames silencieuses (13.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0066 (percentile 90)
#       Après seuil + distance min (1.0s) : 283 ruptures candidates
#       Résultat final : 283 ruptures → 284 segments
#       → 0.00s
# [5/5] Segmentation terminée : 284 segments  → 0.01s
#       Durée totale : 10.05s
# [1/5] Chargement : ../exports/tf1_2025-03-10_02-00-00Z_2025-03-10_02-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.11s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00734 (percentile 8.0) → 11218 frames silencieuses (14.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.77s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0064 (percentile 90)
#       Après seuil + distance min (1.0s) : 273 ruptures candidates
#       Résultat final : 273 ruptures → 274 segments
#       → 0.00s
# [5/5] Segmentation terminée : 274 segments  → 0.01s
#       Durée totale : 10.20s
# [1/5] Chargement : ../exports/tf1_2025-03-10_02-30-00Z_2025-03-10_03-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00187 (percentile 8.0) → 9361 frames silencieuses (11.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0042 (percentile 90)
#       Après seuil + distance min (1.0s) : 245 ruptures candidates
#       Résultat final : 245 ruptures → 246 segments
#       → 0.00s
# [5/5] Segmentation terminée : 246 segments  → 0.01s
#       Durée totale : 10.02s
# [1/5] Chargement : ../exports/tf1_2025-03-10_03-00-00Z_2025-03-10_03-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.32s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00405 (percentile 8.0) → 10374 frames silencieuses (13.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0078 (percentile 90)
#       Après seuil + distance min (1.0s) : 282 ruptures candidates
#       Résultat final : 282 ruptures → 283 segments
#       → 0.00s
# [5/5] Segmentation terminée : 283 segments  → 0.01s
#       Durée totale : 10.01s
# [1/5] Chargement : ../exports/tf1_2025-03-10_03-30-00Z_2025-03-10_04-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 4.02s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00625 (percentile 8.0) → 10978 frames silencieuses (13.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0081 (percentile 90)
#       Après seuil + distance min (1.0s) : 285 ruptures candidates
#       Résultat final : 285 ruptures → 286 segments
#       → 0.00s
# [5/5] Segmentation terminée : 286 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_04-00-00Z_2025-03-10_04-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.27s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00354 (percentile 8.0) → 10628 frames silencieuses (13.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0062 (percentile 90)
#       Après seuil + distance min (1.0s) : 268 ruptures candidates
#       Résultat final : 268 ruptures → 269 segments
#       → 0.00s
# [5/5] Segmentation terminée : 269 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_04-30-00Z_2025-03-10_05-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00537 (percentile 8.0) → 10963 frames silencieuses (13.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0070 (percentile 90)
#       Après seuil + distance min (1.0s) : 282 ruptures candidates
#       Résultat final : 282 ruptures → 283 segments
#       → 0.00s
# [5/5] Segmentation terminée : 283 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_05-00-00Z_2025-03-10_05-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 4.02s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00790 (percentile 8.0) → 12430 frames silencieuses (15.5%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0080 (percentile 90)
#       Après seuil + distance min (1.0s) : 296 ruptures candidates
#       Résultat final : 296 ruptures → 297 segments
#       → 0.00s
# [5/5] Segmentation terminée : 297 segments  → 0.01s
#       Durée totale : 9.98s
# [1/5] Chargement : ../exports/tf1_2025-03-10_05-30-00Z_2025-03-10_06-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.37s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00745 (percentile 8.0) → 12015 frames silencieuses (15.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0074 (percentile 90)
#       Après seuil + distance min (1.0s) : 282 ruptures candidates
#       Résultat final : 282 ruptures → 283 segments
#       → 0.00s
# [5/5] Segmentation terminée : 283 segments  → 0.01s
#       Durée totale : 10.10s
# [1/5] Chargement : ../exports/tf1_2025-03-10_06-00-00Z_2025-03-10_06-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 4.02s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00380 (percentile 8.0) → 13958 frames silencieuses (17.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0057 (percentile 90)
#       Après seuil + distance min (1.0s) : 342 ruptures candidates
#       Résultat final : 342 ruptures → 343 segments
#       → 0.00s
# [5/5] Segmentation terminée : 343 segments  → 0.01s
#       Durée totale : 10.02s
# [1/5] Chargement : ../exports/tf1_2025-03-10_06-30-00Z_2025-03-10_07-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 3.94s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00506 (percentile 8.0) → 13998 frames silencieuses (17.5%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0063 (percentile 90)
#       Après seuil + distance min (1.0s) : 334 ruptures candidates
#       Résultat final : 334 ruptures → 335 segments
#       → 0.00s
# [5/5] Segmentation terminée : 335 segments  → 0.01s
#       Durée totale : 9.91s
# [1/5] Chargement : ../exports/tf1_2025-03-10_07-00-00Z_2025-03-10_07-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00528 (percentile 8.0) → 13704 frames silencieuses (17.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0063 (percentile 90)
#       Après seuil + distance min (1.0s) : 326 ruptures candidates
#       Résultat final : 326 ruptures → 327 segments
#       → 0.00s
# [5/5] Segmentation terminée : 327 segments  → 0.01s
#       Durée totale : 9.96s
# [1/5] Chargement : ../exports/tf1_2025-03-10_07-30-00Z_2025-03-10_08-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00470 (percentile 8.0) → 13585 frames silencieuses (17.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0067 (percentile 90)
#       Après seuil + distance min (1.0s) : 331 ruptures candidates
#       Résultat final : 331 ruptures → 332 segments
#       → 0.00s
# [5/5] Segmentation terminée : 332 segments  → 0.01s
#       Durée totale : 9.94s
# [1/5] Chargement : ../exports/tf1_2025-03-10_08-00-00Z_2025-03-10_08-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00477 (percentile 8.0) → 13429 frames silencieuses (16.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0067 (percentile 90)
#       Après seuil + distance min (1.0s) : 339 ruptures candidates
#       Résultat final : 339 ruptures → 340 segments
#       → 0.00s
# [5/5] Segmentation terminée : 340 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_08-30-00Z_2025-03-10_09-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 3.90s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.01037 (percentile 8.0) → 15725 frames silencieuses (19.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.68s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0081 (percentile 90)
#       Après seuil + distance min (1.0s) : 309 ruptures candidates
#       Résultat final : 309 ruptures → 310 segments
#       → 0.00s
# [5/5] Segmentation terminée : 310 segments  → 0.01s
#       Durée totale : 9.89s
# [1/5] Chargement : ../exports/tf1_2025-03-10_09-00-00Z_2025-03-10_09-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00982 (percentile 8.0) → 16192 frames silencieuses (20.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0072 (percentile 90)
#       Après seuil + distance min (1.0s) : 312 ruptures candidates
#       Résultat final : 312 ruptures → 313 segments
#       → 0.00s
# [5/5] Segmentation terminée : 313 segments  → 0.01s
#       Durée totale : 9.98s
# [1/5] Chargement : ../exports/tf1_2025-03-10_09-30-00Z_2025-03-10_10-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.33s
# [2/5] Extraction des features...
#       → 3.97s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00233 (percentile 8.0) → 9425 frames silencieuses (11.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 263 ruptures candidates
#       Résultat final : 263 ruptures → 264 segments
#       → 0.00s
# [5/5] Segmentation terminée : 264 segments  → 0.01s
#       Durée totale : 9.96s
# [1/5] Chargement : ../exports/tf1_2025-03-10_10-00-00Z_2025-03-10_10-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00543 (percentile 8.0) → 10112 frames silencieuses (12.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0047 (percentile 90)
#       Après seuil + distance min (1.0s) : 247 ruptures candidates
#       Résultat final : 247 ruptures → 248 segments
#       → 0.00s
# [5/5] Segmentation terminée : 248 segments  → 0.01s
#       Durée totale : 9.99s
# [1/5] Chargement : ../exports/tf1_2025-03-10_10-30-00Z_2025-03-10_11-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 4.08s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00755 (percentile 8.0) → 11541 frames silencieuses (14.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.64s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0062 (percentile 90)
#       Après seuil + distance min (1.0s) : 272 ruptures candidates
#       Résultat final : 272 ruptures → 273 segments
#       → 0.00s
# [5/5] Segmentation terminée : 273 segments  → 0.01s
#       Durée totale : 10.07s
# [1/5] Chargement : ../exports/tf1_2025-03-10_11-00-00Z_2025-03-10_11-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00833 (percentile 8.0) → 12567 frames silencieuses (15.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0073 (percentile 90)
#       Après seuil + distance min (1.0s) : 314 ruptures candidates
#       Résultat final : 314 ruptures → 315 segments
#       → 0.00s
# [5/5] Segmentation terminée : 315 segments  → 0.01s
#       Durée totale : 10.03s
# [1/5] Chargement : ../exports/tf1_2025-03-10_11-30-00Z_2025-03-10_12-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 3.91s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00680 (percentile 8.0) → 11378 frames silencieuses (14.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0074 (percentile 90)
#       Après seuil + distance min (1.0s) : 264 ruptures candidates
#       Résultat final : 264 ruptures → 265 segments
#       → 0.00s
# [5/5] Segmentation terminée : 265 segments  → 0.01s
#       Durée totale : 9.86s
# [1/5] Chargement : ../exports/tf1_2025-03-10_12-00-00Z_2025-03-10_12-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 3.97s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00445 (percentile 8.0) → 12286 frames silencieuses (15.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0055 (percentile 90)
#       Après seuil + distance min (1.0s) : 305 ruptures candidates
#       Résultat final : 305 ruptures → 306 segments
#       → 0.00s
# [5/5] Segmentation terminée : 306 segments  → 0.01s
#       Durée totale : 9.93s
# [1/5] Chargement : ../exports/tf1_2025-03-10_12-30-00Z_2025-03-10_13-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 4.00s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00754 (percentile 8.0) → 13607 frames silencieuses (17.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0069 (percentile 90)
#       Après seuil + distance min (1.0s) : 289 ruptures candidates
#       Résultat final : 289 ruptures → 290 segments
#       → 0.00s
# [5/5] Segmentation terminée : 290 segments  → 0.01s
#       Durée totale : 10.02s
# [1/5] Chargement : ../exports/tf1_2025-03-10_13-00-00Z_2025-03-10_13-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.39s
# [2/5] Extraction des features...
#       → 4.04s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00835 (percentile 8.0) → 11462 frames silencieuses (14.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.69s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0055 (percentile 90)
#       Après seuil + distance min (1.0s) : 280 ruptures candidates
#       Résultat final : 280 ruptures → 281 segments
#       → 0.00s
# [5/5] Segmentation terminée : 281 segments  → 0.01s
#       Durée totale : 10.13s
# [1/5] Chargement : ../exports/tf1_2025-03-10_13-30-00Z_2025-03-10_14-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 4.02s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00403 (percentile 8.0) → 9518 frames silencieuses (11.9%)
#       Lissage             : 21 frames = 0.49s
#       → 1.75s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0040 (percentile 90)
#       Après seuil + distance min (1.0s) : 227 ruptures candidates
#       Résultat final : 227 ruptures → 228 segments
#       → 0.00s
# [5/5] Segmentation terminée : 228 segments  → 0.01s
#       Durée totale : 10.12s
# [1/5] Chargement : ../exports/tf1_2025-03-10_14-00-00Z_2025-03-10_14-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.38s
# [2/5] Extraction des features...
#       → 4.00s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00312 (percentile 8.0) → 8922 frames silencieuses (11.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0040 (percentile 90)
#       Après seuil + distance min (1.0s) : 221 ruptures candidates
#       Résultat final : 221 ruptures → 222 segments
#       → 0.00s
# [5/5] Segmentation terminée : 222 segments  → 0.01s
#       Durée totale : 10.08s
# [1/5] Chargement : ../exports/tf1_2025-03-10_14-30-00Z_2025-03-10_15-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00750 (percentile 8.0) → 10261 frames silencieuses (12.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 264 ruptures candidates
#       Résultat final : 264 ruptures → 265 segments
#       → 0.00s
# [5/5] Segmentation terminée : 265 segments  → 0.01s
#       Durée totale : 9.96s
# [1/5] Chargement : ../exports/tf1_2025-03-10_15-00-00Z_2025-03-10_15-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 3.95s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00625 (percentile 8.0) → 9724 frames silencieuses (12.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0041 (percentile 90)
#       Après seuil + distance min (1.0s) : 247 ruptures candidates
#       Résultat final : 247 ruptures → 248 segments
#       → 0.00s
# [5/5] Segmentation terminée : 248 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_15-30-00Z_2025-03-10_16-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.38s
# [2/5] Extraction des features...
#       → 4.05s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00507 (percentile 8.0) → 9302 frames silencieuses (11.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.75s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0024 (percentile 90)
#       Après seuil + distance min (1.0s) : 198 ruptures candidates
#       Résultat final : 198 ruptures → 199 segments
#       → 0.00s
# [5/5] Segmentation terminée : 199 segments  → 0.01s
#       Durée totale : 10.19s
# [1/5] Chargement : ../exports/tf1_2025-03-10_16-00-00Z_2025-03-10_16-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 3.96s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00491 (percentile 8.0) → 9860 frames silencieuses (12.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0031 (percentile 90)
#       Après seuil + distance min (1.0s) : 215 ruptures candidates
#       Résultat final : 215 ruptures → 216 segments
#       → 0.00s
# [5/5] Segmentation terminée : 216 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_16-30-00Z_2025-03-10_17-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.01215 (percentile 8.0) → 12881 frames silencieuses (16.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0087 (percentile 90)
#       Après seuil + distance min (1.0s) : 304 ruptures candidates
#       Résultat final : 304 ruptures → 305 segments
#       → 0.00s
# [5/5] Segmentation terminée : 305 segments  → 0.01s
#       Durée totale : 9.89s
# [1/5] Chargement : ../exports/tf1_2025-03-10_17-00-00Z_2025-03-10_17-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.37s
# [2/5] Extraction des features...
#       → 4.10s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00889 (percentile 8.0) → 13117 frames silencieuses (16.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.72s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0078 (percentile 90)
#       Après seuil + distance min (1.0s) : 305 ruptures candidates
#       Résultat final : 305 ruptures → 306 segments
#       → 0.00s
# [5/5] Segmentation terminée : 306 segments  → 0.01s
#       Durée totale : 10.20s
# [1/5] Chargement : ../exports/tf1_2025-03-10_17-30-00Z_2025-03-10_18-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.37s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00419 (percentile 8.0) → 9951 frames silencieuses (12.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0046 (percentile 90)
#       Après seuil + distance min (1.0s) : 260 ruptures candidates
#       Résultat final : 260 ruptures → 261 segments
#       → 0.00s
# [5/5] Segmentation terminée : 261 segments  → 0.01s
#       Durée totale : 10.07s
# [1/5] Chargement : ../exports/tf1_2025-03-10_18-00-00Z_2025-03-10_18-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00417 (percentile 8.0) → 9908 frames silencieuses (12.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0037 (percentile 90)
#       Après seuil + distance min (1.0s) : 235 ruptures candidates
#       Résultat final : 235 ruptures → 236 segments
#       → 0.00s
# [5/5] Segmentation terminée : 236 segments  → 0.01s
#       Durée totale : 9.91s
# [1/5] Chargement : ../exports/tf1_2025-03-10_18-30-00Z_2025-03-10_19-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00446 (percentile 8.0) → 10738 frames silencieuses (13.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 266 ruptures candidates
#       Résultat final : 266 ruptures → 267 segments
#       → 0.00s
# [5/5] Segmentation terminée : 267 segments  → 0.01s
#       Durée totale : 9.94s
# [1/5] Chargement : ../exports/tf1_2025-03-10_19-00-00Z_2025-03-10_19-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.26s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00266 (percentile 8.0) → 11499 frames silencieuses (14.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0062 (percentile 90)
#       Après seuil + distance min (1.0s) : 309 ruptures candidates
#       Résultat final : 309 ruptures → 310 segments
#       → 0.00s
# [5/5] Segmentation terminée : 310 segments  → 0.01s
#       Durée totale : 9.93s
# [1/5] Chargement : ../exports/tf1_2025-03-10_19-30-00Z_2025-03-10_20-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.32s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00752 (percentile 8.0) → 11682 frames silencieuses (14.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0075 (percentile 90)
#       Après seuil + distance min (1.0s) : 274 ruptures candidates
#       Résultat final : 274 ruptures → 275 segments
#       → 0.00s
# [5/5] Segmentation terminée : 275 segments  → 0.01s
#       Durée totale : 9.93s
# [1/5] Chargement : ../exports/tf1_2025-03-10_20-00-00Z_2025-03-10_20-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 3.96s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00657 (percentile 8.0) → 10524 frames silencieuses (13.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 254 ruptures candidates
#       Résultat final : 254 ruptures → 255 segments
#       → 0.00s
# [5/5] Segmentation terminée : 255 segments  → 0.01s
#       Durée totale : 9.91s
# [1/5] Chargement : ../exports/tf1_2025-03-10_20-30-00Z_2025-03-10_21-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.00s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00302 (percentile 8.0) → 9945 frames silencieuses (12.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0030 (percentile 90)
#       Après seuil + distance min (1.0s) : 229 ruptures candidates
#       Résultat final : 229 ruptures → 230 segments
#       → 0.00s
# [5/5] Segmentation terminée : 230 segments  → 0.01s
#       Durée totale : 9.98s
# [1/5] Chargement : ../exports/tf1_2025-03-10_21-00-00Z_2025-03-10_21-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.32s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00308 (percentile 8.0) → 9151 frames silencieuses (11.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0027 (percentile 90)
#       Après seuil + distance min (1.0s) : 213 ruptures candidates
#       Résultat final : 213 ruptures → 214 segments
#       → 0.00s
# [5/5] Segmentation terminée : 214 segments  → 0.01s
#       Durée totale : 9.98s
# [1/5] Chargement : ../exports/tf1_2025-03-10_21-30-00Z_2025-03-10_22-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 3.99s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00265 (percentile 8.0) → 9257 frames silencieuses (11.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0018 (percentile 90)
#       Après seuil + distance min (1.0s) : 200 ruptures candidates
#       Résultat final : 200 ruptures → 201 segments
#       → 0.00s
# [5/5] Segmentation terminée : 201 segments  → 0.01s
#       Durée totale : 9.96s
# [1/5] Chargement : ../exports/tf1_2025-03-10_22-00-00Z_2025-03-10_22-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00574 (percentile 8.0) → 9484 frames silencieuses (11.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0035 (percentile 90)
#       Après seuil + distance min (1.0s) : 224 ruptures candidates
#       Résultat final : 224 ruptures → 225 segments
#       → 0.00s
# [5/5] Segmentation terminée : 225 segments  → 0.01s
#       Durée totale : 9.97s
# [1/5] Chargement : ../exports/tf1_2025-03-10_22-30-00Z_2025-03-10_23-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.27s
# [2/5] Extraction des features...
#       → 3.97s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00501 (percentile 8.0) → 9393 frames silencieuses (11.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.69s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0049 (percentile 90)
#       Après seuil + distance min (1.0s) : 249 ruptures candidates
#       Résultat final : 249 ruptures → 250 segments
#       → 0.00s
# [5/5] Segmentation terminée : 250 segments  → 0.01s
#       Durée totale : 9.94s
# [1/5] Chargement : ../exports/tf1_2025-03-10_23-00-00Z_2025-03-10_23-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.33s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00991 (percentile 8.0) → 10221 frames silencieuses (12.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.72s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0054 (percentile 90)
#       Après seuil + distance min (1.0s) : 245 ruptures candidates
#       Résultat final : 245 ruptures → 246 segments
#       → 0.00s
# [5/5] Segmentation terminée : 246 segments  → 0.01s
#       Durée totale : 10.07s
# [1/5] Chargement : ../exports/tf1_2025-03-10_23-30-00Z_2025-03-11_00-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.27s
# [2/5] Extraction des features...
#       → 4.04s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00627 (percentile 8.0) → 9718 frames silencieuses (12.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 249 ruptures candidates
#       Résultat final : 249 ruptures → 250 segments
#       → 0.00s
# [5/5] Segmentation terminée : 250 segments  → 0.01s
#       Durée totale : 9.96s
# [1/5] Chargement : ../exports/tf1_2025-03-11_00-00-00Z_2025-03-11_00-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 4.02s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00844 (percentile 8.0) → 10253 frames silencieuses (12.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0067 (percentile 90)
#       Après seuil + distance min (1.0s) : 258 ruptures candidates
#       Résultat final : 258 ruptures → 259 segments
#       → 0.00s
# [5/5] Segmentation terminée : 259 segments  → 0.01s
#       Durée totale : 10.01s
# [1/5] Chargement : ../exports/tf1_2025-03-11_00-30-00Z_2025-03-11_01-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 3.92s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00443 (percentile 8.0) → 9303 frames silencieuses (11.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0043 (percentile 90)
#       Après seuil + distance min (1.0s) : 236 ruptures candidates
#       Résultat final : 236 ruptures → 237 segments
#       → 0.00s
# [5/5] Segmentation terminée : 237 segments  → 0.01s
#       Durée totale : 9.87s
# [1/5] Chargement : ../exports/tf1_2025-03-11_01-00-00Z_2025-03-11_01-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.26s
# [2/5] Extraction des features...
#       → 3.95s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00314 (percentile 8.0) → 9295 frames silencieuses (11.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0046 (percentile 90)
#       Après seuil + distance min (1.0s) : 246 ruptures candidates
#       Résultat final : 246 ruptures → 247 segments
#       → 0.00s
# [5/5] Segmentation terminée : 247 segments  → 0.01s
#       Durée totale : 9.89s
# [1/5] Chargement : ../exports/tf1_2025-03-11_01-30-00Z_2025-03-11_02-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 3.98s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00285 (percentile 8.0) → 8399 frames silencieuses (10.5%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0011 (percentile 90)
#       Après seuil + distance min (1.0s) : 183 ruptures candidates
#       Résultat final : 183 ruptures → 184 segments
#       → 0.00s
# [5/5] Segmentation terminée : 184 segments  → 0.00s
#       Durée totale : 9.94s
# [1/5] Chargement : ../exports/tf1_2025-03-11_02-00-00Z_2025-03-11_02-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00668 (percentile 8.0) → 11639 frames silencieuses (14.5%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0064 (percentile 90)
#       Après seuil + distance min (1.0s) : 308 ruptures candidates
#       Résultat final : 308 ruptures → 309 segments
#       → 0.00s
# [5/5] Segmentation terminée : 309 segments  → 0.01s
#       Durée totale : 10.00s
# [1/5] Chargement : ../exports/tf1_2025-03-11_02-30-00Z_2025-03-11_03-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 4.11s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00789 (percentile 8.0) → 11823 frames silencieuses (14.8%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0064 (percentile 90)
#       Après seuil + distance min (1.0s) : 293 ruptures candidates
#       Résultat final : 293 ruptures → 294 segments
#       → 0.00s
# [5/5] Segmentation terminée : 294 segments  → 0.01s
#       Durée totale : 10.08s
# [1/5] Chargement : ../exports/tf1_2025-03-11_03-00-00Z_2025-03-11_03-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.32s
# [2/5] Extraction des features...
#       → 4.05s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00631 (percentile 8.0) → 11705 frames silencieuses (14.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.69s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0057 (percentile 90)
#       Après seuil + distance min (1.0s) : 302 ruptures candidates
#       Résultat final : 302 ruptures → 303 segments
#       → 0.00s
# [5/5] Segmentation terminée : 303 segments  → 0.01s
#       Durée totale : 10.07s
# [1/5] Chargement : ../exports/tf1_2025-03-11_03-30-00Z_2025-03-11_04-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00672 (percentile 8.0) → 11429 frames silencieuses (14.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 261 ruptures candidates
#       Résultat final : 261 ruptures → 262 segments
#       → 0.00s
# [5/5] Segmentation terminée : 262 segments  → 0.01s
#       Durée totale : 10.02s
# [1/5] Chargement : ../exports/tf1_2025-03-11_04-00-00Z_2025-03-11_04-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.33s
# [2/5] Extraction des features...
#       → 3.92s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00781 (percentile 8.0) → 10897 frames silencieuses (13.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0046 (percentile 90)
#       Après seuil + distance min (1.0s) : 277 ruptures candidates
#       Résultat final : 277 ruptures → 278 segments
#       → 0.00s
# [5/5] Segmentation terminée : 278 segments  → 0.01s
#       Durée totale : 9.91s
# [1/5] Chargement : ../exports/tf1_2025-03-11_04-30-00Z_2025-03-11_05-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 3.96s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00345 (percentile 8.0) → 10090 frames silencieuses (12.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0038 (percentile 90)
#       Après seuil + distance min (1.0s) : 248 ruptures candidates
#       Résultat final : 248 ruptures → 249 segments
#       → 0.00s
# [5/5] Segmentation terminée : 249 segments  → 0.01s
#       Durée totale : 10.00s
# [1/5] Chargement : ../exports/tf1_2025-03-11_05-00-00Z_2025-03-11_05-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 4.06s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00703 (percentile 8.0) → 12829 frames silencieuses (16.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.71s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0094 (percentile 90)
#       Après seuil + distance min (1.0s) : 296 ruptures candidates
#       Résultat final : 296 ruptures → 297 segments
#       → 0.00s
# [5/5] Segmentation terminée : 297 segments  → 0.01s
#       Durée totale : 10.13s
# [1/5] Chargement : ../exports/tf1_2025-03-11_05-30-00Z_2025-03-11_06-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.33s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00660 (percentile 8.0) → 12088 frames silencieuses (15.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0075 (percentile 90)
#       Après seuil + distance min (1.0s) : 293 ruptures candidates
#       Résultat final : 293 ruptures → 294 segments
#       → 0.00s
# [5/5] Segmentation terminée : 294 segments  → 0.01s
#       Durée totale : 10.02s
# [1/5] Chargement : ../exports/tf1_2025-03-11_06-00-00Z_2025-03-11_06-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.24s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00373 (percentile 8.0) → 13796 frames silencieuses (17.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0066 (percentile 90)
#       Après seuil + distance min (1.0s) : 331 ruptures candidates
#       Résultat final : 331 ruptures → 332 segments
#       → 0.00s
# [5/5] Segmentation terminée : 332 segments  → 0.01s
#       Durée totale : 9.85s
# [1/5] Chargement : ../exports/tf1_2025-03-11_06-30-00Z_2025-03-11_07-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 3.91s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00435 (percentile 8.0) → 13080 frames silencieuses (16.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0057 (percentile 90)
#       Après seuil + distance min (1.0s) : 314 ruptures candidates
#       Résultat final : 314 ruptures → 315 segments
#       → 0.00s
# [5/5] Segmentation terminée : 315 segments  → 0.01s
#       Durée totale : 9.88s
# [1/5] Chargement : ../exports/tf1_2025-03-11_07-00-00Z_2025-03-11_07-31-00Z.mp3
# ...
#       → 0.00s
# [5/5] Segmentation terminée : 277 segments  → 0.01s
#       Durée totale : 9.98s
# [1/5] Chargement : ../exports/tf1_2025-03-12_11-00-00Z_2025-03-12_11-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.03s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00851 (percentile 8.0) → 11805 frames silencieuses (14.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.67s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0082 (percentile 90)
#       Après seuil + distance min (1.0s) : 282 ruptures candidates
#       Résultat final : 282 ruptures → 283 segments
#       → 0.00s
# [5/5] Segmentation terminée : 283 segments  → 0.01s
#       Durée totale : 10.01s
# [1/5] Chargement : ../exports/tf1_2025-03-12_11-30-00Z_2025-03-12_12-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.29s
# [2/5] Extraction des features...
#       → 4.08s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00602 (percentile 8.0) → 11373 frames silencieuses (14.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0073 (percentile 90)
#       Après seuil + distance min (1.0s) : 271 ruptures candidates
#       Résultat final : 271 ruptures → 272 segments
#       → 0.00s
# [5/5] Segmentation terminée : 272 segments  → 0.01s
#       Durée totale : 10.08s
# [1/5] Chargement : ../exports/tf1_2025-03-12_12-00-00Z_2025-03-12_12-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.26s
# [2/5] Extraction des features...
#       → 4.32s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00404 (percentile 8.0) → 12352 frames silencieuses (15.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0061 (percentile 90)
#       Après seuil + distance min (1.0s) : 334 ruptures candidates
#       Résultat final : 334 ruptures → 335 segments
#       → 0.00s
# [5/5] Segmentation terminée : 335 segments  → 0.01s
#       Durée totale : 10.23s
# [1/5] Chargement : ../exports/tf1_2025-03-12_12-30-00Z_2025-03-12_13-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 3.98s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00552 (percentile 8.0) → 11777 frames silencieuses (14.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.71s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0066 (percentile 90)
#       Après seuil + distance min (1.0s) : 281 ruptures candidates
#       Résultat final : 281 ruptures → 282 segments
#       → 0.00s
# [5/5] Segmentation terminée : 282 segments  → 0.01s
#       Durée totale : 10.05s
# [1/5] Chargement : ../exports/tf1_2025-03-12_13-00-00Z_2025-03-12_13-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.33s
# [2/5] Extraction des features...
#       → 4.05s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00586 (percentile 8.0) → 10778 frames silencieuses (13.5%)
#       Lissage             : 21 frames = 0.49s
#       → 1.69s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0044 (percentile 90)
#       Après seuil + distance min (1.0s) : 255 ruptures candidates
#       Résultat final : 255 ruptures → 256 segments
#       → 0.00s
# [5/5] Segmentation terminée : 256 segments  → 0.01s
#       Durée totale : 10.08s
# [1/5] Chargement : ../exports/tf1_2025-03-12_13-30-00Z_2025-03-12_14-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 4.01s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00455 (percentile 8.0) → 11334 frames silencieuses (14.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.72s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0057 (percentile 90)
#       Après seuil + distance min (1.0s) : 292 ruptures candidates
#       Résultat final : 292 ruptures → 293 segments
#       → 0.00s
# [5/5] Segmentation terminée : 293 segments  → 0.01s
#       Durée totale : 10.08s
# [1/5] Chargement : ../exports/tf1_2025-03-12_14-00-00Z_2025-03-12_14-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.26s
# [2/5] Extraction des features...
#       → 4.06s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00400 (percentile 8.0) → 11000 frames silencieuses (13.7%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0053 (percentile 90)
#       Après seuil + distance min (1.0s) : 294 ruptures candidates
#       Résultat final : 294 ruptures → 295 segments
#       → 0.00s
# [5/5] Segmentation terminée : 295 segments  → 0.01s
#       Durée totale : 9.98s
# [1/5] Chargement : ../exports/tf1_2025-03-12_14-30-00Z_2025-03-12_15-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.06s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00533 (percentile 8.0) → 10363 frames silencieuses (12.9%)
#       Lissage             : 21 frames = 0.49s
#       → 1.68s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0055 (percentile 90)
#       Après seuil + distance min (1.0s) : 276 ruptures candidates
#       Résultat final : 276 ruptures → 277 segments
#       → 0.00s
# [5/5] Segmentation terminée : 277 segments  → 0.01s
#       Durée totale : 10.06s
# [1/5] Chargement : ../exports/tf1_2025-03-12_15-00-00Z_2025-03-12_15-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.41s
# [2/5] Extraction des features...
#       → 4.04s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00626 (percentile 8.0) → 9610 frames silencieuses (12.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.70s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0024 (percentile 90)
#       Après seuil + distance min (1.0s) : 218 ruptures candidates
#       Résultat final : 218 ruptures → 219 segments
#       → 0.00s
# [5/5] Segmentation terminée : 219 segments  → 0.01s
#       Durée totale : 10.16s
# [1/5] Chargement : ../exports/tf1_2025-03-12_15-30-00Z_2025-03-12_16-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.36s
# [2/5] Extraction des features...
#       → 4.07s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00455 (percentile 8.0) → 10419 frames silencieuses (13.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0039 (percentile 90)
#       Après seuil + distance min (1.0s) : 253 ruptures candidates
#       Résultat final : 253 ruptures → 254 segments
#       → 0.00s
# [5/5] Segmentation terminée : 254 segments  → 0.01s
#       Durée totale : 10.09s
# [1/5] Chargement : ../exports/tf1_2025-03-12_16-00-00Z_2025-03-12_16-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 3.94s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00447 (percentile 8.0) → 9120 frames silencieuses (11.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0026 (percentile 90)
#       Après seuil + distance min (1.0s) : 218 ruptures candidates
#       Résultat final : 218 ruptures → 219 segments
#       → 0.00s
# [5/5] Segmentation terminée : 219 segments  → 0.01s
#       Durée totale : 9.94s
# [1/5] Chargement : ../exports/tf1_2025-03-12_16-30-00Z_2025-03-12_17-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
#       → 4.02s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00912 (percentile 8.0) → 12181 frames silencieuses (15.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0066 (percentile 90)
#       Après seuil + distance min (1.0s) : 291 ruptures candidates
#       Résultat final : 291 ruptures → 292 segments
#       → 0.00s
# [5/5] Segmentation terminée : 292 segments  → 0.01s
#       Durée totale : 10.01s
# [1/5] Chargement : ../exports/tf1_2025-03-12_17-00-00Z_2025-03-12_17-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 4.08s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.01135 (percentile 8.0) → 12995 frames silencieuses (16.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0078 (percentile 90)
#       Après seuil + distance min (1.0s) : 292 ruptures candidates
#       Résultat final : 292 ruptures → 293 segments
#       → 0.00s
# [5/5] Segmentation terminée : 293 segments  → 0.01s
#       Durée totale : 10.09s
# [1/5] Chargement : ../exports/tf1_2025-03-12_17-30-00Z_2025-03-12_18-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.33s
# [2/5] Extraction des features...
#       → 3.92s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00380 (percentile 8.0) → 9550 frames silencieuses (11.9%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0041 (percentile 90)
#       Après seuil + distance min (1.0s) : 246 ruptures candidates
#       Résultat final : 246 ruptures → 247 segments
#       → 0.00s
# [5/5] Segmentation terminée : 247 segments  → 0.01s
#       Durée totale : 9.91s
# [1/5] Chargement : ../exports/tf1_2025-03-12_18-00-00Z_2025-03-12_18-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.37s
# [2/5] Extraction des features...
#       → 3.94s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00338 (percentile 8.0) → 9805 frames silencieuses (12.2%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0041 (percentile 90)
#       Après seuil + distance min (1.0s) : 240 ruptures candidates
#       Résultat final : 240 ruptures → 241 segments
#       → 0.00s
# [5/5] Segmentation terminée : 241 segments  → 0.01s
#       Durée totale : 9.99s
# [1/5] Chargement : ../exports/tf1_2025-03-12_18-30-00Z_2025-03-12_19-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.00s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00608 (percentile 8.0) → 10656 frames silencieuses (13.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.69s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0044 (percentile 90)
#       Après seuil + distance min (1.0s) : 258 ruptures candidates
#       Résultat final : 258 ruptures → 259 segments
#       → 0.00s
# [5/5] Segmentation terminée : 259 segments  → 0.01s
#       Durée totale : 10.00s
# [1/5] Chargement : ../exports/tf1_2025-03-12_19-00-00Z_2025-03-12_19-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.35s
# [2/5] Extraction des features...
#       → 3.93s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00346 (percentile 8.0) → 12025 frames silencieuses (15.0%)
#       Lissage             : 21 frames = 0.49s
#       → 1.75s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0062 (percentile 90)
#       Après seuil + distance min (1.0s) : 331 ruptures candidates
#       Résultat final : 331 ruptures → 332 segments
#       → 0.00s
# [5/5] Segmentation terminée : 332 segments  → 0.01s
#       Durée totale : 10.04s
# [1/5] Chargement : ../exports/tf1_2025-03-12_19-30-00Z_2025-03-12_20-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.28s
# [2/5] Extraction des features...
#       → 3.98s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00661 (percentile 8.0) → 11728 frames silencieuses (14.6%)
#       Lissage             : 21 frames = 0.49s
#       → 1.65s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0074 (percentile 90)
#       Après seuil + distance min (1.0s) : 274 ruptures candidates
#       Résultat final : 274 ruptures → 275 segments
#       → 0.00s
# [5/5] Segmentation terminée : 275 segments  → 0.01s
#       Durée totale : 9.93s
# [1/5] Chargement : ../exports/tf1_2025-03-12_20-00-00Z_2025-03-12_20-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.31s
# [2/5] Extraction des features...
#       → 4.11s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00525 (percentile 8.0) → 10707 frames silencieuses (13.4%)
#       Lissage             : 21 frames = 0.49s
#       → 1.72s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0051 (percentile 90)
#       Après seuil + distance min (1.0s) : 276 ruptures candidates
#       Résultat final : 276 ruptures → 277 segments
#       → 0.00s
# [5/5] Segmentation terminée : 277 segments  → 0.01s
#       Durée totale : 10.15s
# [1/5] Chargement : ../exports/tf1_2025-03-12_20-30-00Z_2025-03-12_21-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.32s
# [2/5] Extraction des features...
#       → 3.96s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00482 (percentile 8.0) → 10522 frames silencieuses (13.1%)
#       Lissage             : 21 frames = 0.49s
#       → 1.66s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0045 (percentile 90)
#       Après seuil + distance min (1.0s) : 263 ruptures candidates
#       Résultat final : 263 ruptures → 264 segments
#       → 0.00s
# [5/5] Segmentation terminée : 264 segments  → 0.01s
#       Durée totale : 9.96s
# [1/5] Chargement : ../exports/tf1_2025-03-12_21-00-00Z_2025-03-12_21-31-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.30s
# [2/5] Extraction des features...
#       → 3.95s
# [3/5] Calcul de la courbe de nouveauté...
#       Fenêtre de contexte : 43 frames = 1.00s de chaque côté
#       Seuil silence       : énergie < 0.00497 (percentile 8.0) → 9856 frames silencieuses (12.3%)
#       Lissage             : 21 frames = 0.49s
#       → 1.75s
# [4/5] Détection des frontières...
#       Seuil sensitivity=0.10 → hauteur min 0.0040 (percentile 90)
#       Après seuil + distance min (1.0s) : 242 ruptures candidates
#       Résultat final : 242 ruptures → 243 segments
#       → 0.00s
# [5/5] Segmentation terminée : 243 segments  → 0.01s
#       Durée totale : 10.01s
# [1/5] Chargement : ../exports/tf1_2025-03-12_21-30-00Z_2025-03-12_22-01-00Z.mp3
#       Durée : 1860.0s  (31.0 min)
#       → 4.34s
# [2/5] Extraction des features...
