# %%
import os
import sys

repo_root_path = os.path.abspath(os.path.join("..", "..", ".."))

if repo_root_path not in sys.path:
    sys.path.append(repo_root_path)

# %%
from datetime import datetime
from zoneinfo import ZoneInfo
from analyse.advertising.e01_rupture_detection.split_chunks import (
    split_week_in_segments,
)

tz_paris = ZoneInfo("Europe/Paris")
channel = "tf1"

MONDAY_LAST_YEAR = datetime(2025, 3, 10, tzinfo=tz_paris)

# %%
SEGMENTS_FOLDER = os.path.join("./exports", f"segments_{channel}_{MONDAY_LAST_YEAR.strftime('%Y%m%d')}")

if not os.path.exists(SEGMENTS_FOLDER):
    os.makedirs(SEGMENTS_FOLDER)
    print(f"Created folder for new extraction: {SEGMENTS_FOLDER}")
    split_week_in_segments(channel, MONDAY_LAST_YEAR, SEGMENTS_FOLDER)
# Out:
# Created folder for new extraction: ./exports/segments_tf1_20250310
# ...
# [1/5] Chargement : ../exports/tf1_2025-03-09_23-00-00_2025-03-10_00-00-00.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 os.makedirs(SEGMENTS_FOLDER)
#       5 print(f"Created folder for new extraction: {SEGMENTS_FOLDER}")
# ----> 6 split_week_in_segments(channel, MONDAY_LAST_YEAR, SEGMENTS_FOLDER)
#
# File ~/Workspace/quotaclimat/analyse/advertising/e01_rupture_detection/split_chunks.py:58, in split_week_in_segments(channel, week_start_date, output_folder)
#      53 export_file = api.download_export(channel, start_date, end_date)
#      54 output_file = os.path.join(
#      55     output_folder,
#      56     f"{start_date.strftime('%Y-%m-%d_%H-%M-%S')}.json",
#      57 )
# ---> 58 split_and_save_chunks(export_file, output_file)
#
# ...
