# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

repo_root_path = os.path.abspath(os.path.join("..", "..", ".."))

if repo_root_path not in sys.path:
    sys.path.append(repo_root_path)

# %%
from datetime import datetime
from zoneinfo import ZoneInfo
from analyse.advertising.e01_rupture_detection.split_chunks import (
    split_week_in_segments,
)

tz_paris = ZoneInfo("Europe/Paris")
channel = "tf1"

MONDAY_LAST_YEAR = datetime(2025, 3, 10, tzinfo=tz_paris)

# %%
SEGMENTS_FOLDER = os.path.join("./exports", f"segments_{channel}_{MONDAY_LAST_YEAR.strftime('%Y%m%d')}")

if not os.path.exists(SEGMENTS_FOLDER):
    os.makedirs(SEGMENTS_FOLDER)
    print(f"Created folder for new extraction: {SEGMENTS_FOLDER}")

await split_week_in_segments(channel, MONDAY_LAST_YEAR, SEGMENTS_FOLDER)
# Out:
# Downloading export for tf1 from 2025-03-12 19:30:00+01:00 to 2025-03-12 20:01:00+01:00...
# Downloading export for tf1 from 2025-03-12 20:00:00+01:00 to 2025-03-12 20:31:00+01:00...
# Downloading export for tf1 from 2025-03-12 20:30:00+01:00 to 2025-03-12 21:01:00+01:00...
# Downloading export for tf1 from 2025-03-12 21:00:00+01:00 to 2025-03-12 21:31:00+01:00...
# Downloading export for tf1 from 2025-03-12 21:30:00+01:00 to 2025-03-12 22:01:00+01:00...
# Downloading export for tf1 from 2025-03-12 22:00:00+01:00 to 2025-03-12 22:31:00+01:00...
# Downloading export for tf1 from 2025-03-12 22:30:00+01:00 to 2025-03-12 23:01:00+01:00...
# Downloading export for tf1 from 2025-03-12 23:00:00+01:00 to 2025-03-12 23:31:00+01:00...
# Downloading export for tf1 from 2025-03-12 23:30:00+01:00 to 2025-03-13 00:01:00+01:00...
# Downloading export for tf1 from 2025-03-13 00:00:00+01:00 to 2025-03-13 00:31:00+01:00...
# Downloading export for tf1 from 2025-03-13 00:30:00+01:00 to 2025-03-13 01:01:00+01:00...
# Downloading export for tf1 from 2025-03-13 01:00:00+01:00 to 2025-03-13 01:31:00+01:00...
# Downloading export for tf1 from 2025-03-13 01:30:00+01:00 to 2025-03-13 02:01:00+01:00...
# Downloading export for tf1 from 2025-03-13 02:00:00+01:00 to 2025-03-13 02:31:00+01:00...
# Downloading export for tf1 from 2025-03-13 02:30:00+01:00 to 2025-03-13 03:01:00+01:00...
# Downloading export for tf1 from 2025-03-13 03:00:00+01:00 to 2025-03-13 03:31:00+01:00...
# Downloading export for tf1 from 2025-03-13 03:30:00+01:00 to 2025-03-13 04:01:00+01:00...
# Downloading export for tf1 from 2025-03-13 04:00:00+01:00 to 2025-03-13 04:31:00+01:00...
