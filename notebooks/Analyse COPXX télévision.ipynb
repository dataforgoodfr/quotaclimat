# %% [markdown]
# # Analyse des occurrences du COPXX dans la description des programmes TV

# %% [markdown]
# ## Création du fichier CSV à partir du dossier avec tous les fichiers CSV

# %%
import create_df_television_news_analyser as analyser

# %%
analyser.create_csv(r"D:\__dossier_essais\DataForGood")

# %% [markdown]
# ## Pré-traitement des données de description

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from Extract_COP import extract_COP_occurences

# %%
cops = extract_COP_occurences("D:\__dossier_essais\DataForGood\data\df_3medias.csv")

# %%
plt.figure(figsize=(10, 5))
plt.title("Apparition du mot COPXX (21 à 27) dans le descriptif des programmes des chaines France2, France3 et TF1")
sns.histplot(data=cops, x="date", hue="media", bins=30, multiple="stack")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Apparition du mot COPXX (21 à 27) dans le descriptif des programmes des chaines France2, France3 et TF1")
sns.histplot(data=cops, x="date", hue="cop", bins=30, multiple="stack", palette=sns.color_palette()[:7])
plt.show()
