# %% [markdown]
# # COP27
# > Ce notebook sert de marche à suivre pour analyser les données d'une journée de COP

# %%
import pandas as pd
import numpy as np
import os
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import datetime

import sys
sys.path.append("../../")

# %load_ext autoreload
# %autoreload 2

from quotaclimat.utils.plotly_theme import *

# %%
# %%html
# <style type="text/css">
# @import url('http://fonts.googleapis.com/css?family=Poppins');
# </style>
# Out:
# <style type="text/css">
# @import url('http://fonts.googleapis.com/css?family=Poppins');
# </style>

# %% [markdown]
# # Récupération et préparation des données

# %% [markdown]
# ## Récupérer et préparer les données de la journée
# Choisissez bien le bon fichier

# %%
from quotaclimat.data_processing.read_format_deduplicate import read_and_format_one
from quotaclimat.data_processing.read_format_deduplicate import read_and_format_all_data_dump
from quotaclimat.data_processing.read_format_deduplicate import deduplicate_extracts

def make_ws_palette(n = 10):
    return [f"rgb({int(x*255)},{int(y*255)},{int(z*255)})" for x,y,z in list(sns.color_palette("RdBu_r",n_colors=n))]

# %%
day = "09"
folder = f"../../data/cop27/{day}11"
paths = [os.path.join(folder,x) for x in os.listdir(folder)]
paths
# Out:
# ['../../data/cop27/0911\\20221110_20221109_20221109_all_COP27.xlsx',
#  '../../data/cop27/0911\\20221110_20221109_20221109_all_écologie.xlsx']

# %%
path_cop27 = [x for x in paths if "cop27" in x.lower()][0]
path_ecologie = [x for x in paths if "écologie" in x.lower()][0]

# IMPORTANT DE RESPECTER CE FORMAT POUR LES FICHIERS
assert "COP27" in path_cop27
assert "écologie" in path_ecologie

# %%
data = read_and_format_one(path_file = path_cop27,path_channels=None)
data.shape
# Out:
# (844, 14)

# %%
data.keyword.unique()
# Out:
# array(['COP27'], dtype=object)

# %% [markdown]
# ## Filtrer sur les 50 chaînes TV et Radio avec le plus d'audience

# %%
top_audiences = pd.read_excel("../../data/channels.xlsx",sheet_name = "top_audiences")
top_audiences["channel_id"] = top_audiences["channel_name"] + "_" + top_audiences["media"]
top_channels_tv = top_audiences.query("media=='TV'")["channel_name"].tolist()
top_channels_radio = top_audiences.query("media=='Radio'")["channel_name"].tolist()

top_channels_tv_gen = top_audiences.query("type=='Généraliste'")["channel_name"].tolist()
top_channels_tv_info = top_audiences.query("type=='Information en continu'")["channel_name"].tolist()

# %%
data["channel_id"] = data["channel_name"] + "_" + data["media"]
data = data.merge(top_audiences[["channel_id","type"]],on = ["channel_id"],how = "inner")

data.loc[data["media"]=="TV","media2"] = "TV" + " - " + data["type"]
data.loc[data["media"]=="Radio","media2"] = "Radio"

data.shape
# Out:
# (206, 17)

# %% [markdown]
# ##### Nombre de chaînes TV ou Radio dans l'échantillon
# Vérifier combien de chaînes sur les 50 parlent du sujet

# %%
data.drop_duplicates(subset = ["channel_name"]).groupby(["media"])["channel_name"].count()
# Out:
# media
# Radio    14
# TV       11
# Name: channel_name, dtype: int64

# %%
data.drop_duplicates(subset = ["channel_name"]).groupby(["media2"])["channel_name"].count()
# Out:
# media2
# Radio                          14
# TV - Généraliste                5
# TV - Information en continu     6
# Name: channel_name, dtype: int64

# %% [markdown]
# ## Filtrer dans les horaires d'antenne entre 6h et minuit

# %%
from quotaclimat.data_analytics.exploration import filter_data_between_hours

# %%
data = filter_data_between_hours(data,"06:00","24:00")

# %%
data.shape
# Out:
# (187, 17)

# %% [markdown]
# # Préparation des analyses

# %%
from quotaclimat.utils.channels import TOP_25_CHANNELS,TOP_CHANNELS_TV,TOP_CHANNELS_TV_8
from quotaclimat.data_analytics.exploration import show_mentions_by_channel
from quotaclimat.data_analytics.exploration import show_mentions_by_time_of_the_day
from quotaclimat.data_analytics.exploration import show_mentions_over_time
from quotaclimat.data_analytics.exploration import show_mentions_treemap
from quotaclimat.data_analytics.exploration import show_piechart_split_tv_radio

# %%
from quotaclimat.utils.plotly_theme import WARMING_STRIPES_SEQUENCE

COLOR_RADIO = WARMING_STRIPES_SEQUENCE[0]
COLOR_TV= WARMING_STRIPES_SEQUENCE[1]
COLOR_ECO = WARMING_STRIPES_SEQUENCE[3]

# %% [markdown]
# ## Analyse 1 - volume médiatique total sur les 50 chaînes

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
n_channels = 25 #TV and Radio

media_time = data.groupby(["media"]).agg({"count":"sum","channel_name":"nunique"})
media_time["n_channels"] = 25
media_time = media_time.append(pd.DataFrame(media_time.sum(axis = 0).rename("Total")).T)
media_time["media_time"] = media_time["count"] * 2
media_time["total_time"] = media_time["n_channels"] * n_days * 18 * 60
media_time["media_part"] = media_time["media_time"] / media_time["total_time"]

media_time
# Out:
#        count  channel_name  n_channels  media_time  total_time  media_part
# Radio    117            13          25         234       27000    0.008667
# TV        70            11          25         140       27000    0.005185
# Total    187            24          50         374       54000    0.006926

# %%
fig = px.bar(media_time.reset_index(),x = "index",y = "media_part",height = 400,text_auto = ".1%")
fig.update_layout(yaxis_tickformat='0%',
                  title = "Volume médiatique total sur les 50 chaînes TV et Radio",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=[COLOR_RADIO,COLOR_TV])
fig
# Out:
# <div>                            <div id="b543a2bf-9856-4c17-bfe2-bf0608cd60f4" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b543a2bf-9856-4c17-bfe2-bf0608cd60f4")) {                    Plotly.newPlot(                        "b543a2bf-9856-4c17-bfe2-bf0608cd60f4",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>media_part=%{y}<extra></extra>","legendgroup":"","marker":{"color":["#08306b","#08519c"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.1%}","x":["Radio","TV","Total"],"xaxis":"x","y":[0.008666666666666666,0.005185185185185185,0.006925925925925926],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ti ...

# %% [markdown]
# ## Analyse 1.2 split par type de TV

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
n_channels = 25 #TV and Radio

media_time = data.groupby(["media2"]).agg({"count":"sum","channel_name":"nunique"})
media_time.loc["Radio","n_channels"] = 25
media_time.loc["TV - Généraliste","n_channels"] = 19
media_time.loc["TV - Information en continu","n_channels"] = 6
media_time = media_time.append(pd.DataFrame(media_time.sum(axis = 0).rename("Total")).T)
media_time["media_time"] = media_time["count"] * 2
media_time["total_time"] = media_time["n_channels"] * n_days * 18 * 60
media_time["media_part"] = media_time["media_time"] / media_time["total_time"]

media_time
# Out:
#                              count  channel_name  n_channels  media_time  \
# Radio                        117.0          13.0        25.0       234.0
# TV - Généraliste               9.0           5.0        19.0        18.0
# TV - Information en continu   61.0           6.0         6.0       122.0
# Total                        187.0          24.0        50.0       374.0
#
#                              total_time  media_part
# Radio                           27000.0    0.008667
# TV - Généraliste                20520.0    0.000877
# TV - Information en continu      6480.0    0.018827
# Total                           54000.0    0.006926

# %%
fig = px.bar(media_time.reset_index(),x = "index",y = "media_part",height = 400,text_auto = ".1%")
fig.update_layout(yaxis_tickformat='0%',
                  title = "Volume médiatique total sur les 50 chaînes TV et Radio",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=[COLOR_RADIO,COLOR_TV,COLOR_TV])
fig
# Out:
# <div>                            <div id="64fe415d-c51d-4a59-9999-0446bc04d95d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64fe415d-c51d-4a59-9999-0446bc04d95d")) {                    Plotly.newPlot(                        "64fe415d-c51d-4a59-9999-0446bc04d95d",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>media_part=%{y}<extra></extra>","legendgroup":"","marker":{"color":["#08306b","#08519c","#08519c"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.1%}","x":["Radio","TV - G\u00e9n\u00e9raliste","TV - Information en continu","Total"],"xaxis":"x","y":[0.008666666666666666,0.0008771929824561404,0.018827160493827162,0.006925925925925926],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{" ...

# %% [markdown]
# ## Analyse 2 - TOP 3 TV et Radio

# %%
# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data,list_of_channels=top_channels_tv_info,n = 3,
                               method = multiplier,height = 400,text_auto = ".1%")
fig.update_layout(yaxis_tickformat='0%',
                  title = "Podium TV - Chaînes d'information en continu",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=COLOR_TV)
fig
# Out:
# <div>                            <div id="74b1766c-ce84-4b4d-9a24-b26a4171a938" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74b1766c-ce84-4b4d-9a24-b26a4171a938")) {                    Plotly.newPlot(                        "74b1766c-ce84-4b4d-9a24-b26a4171a938",                        [{"alignmentgroup":"True","hovertemplate":"media=TV<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TV","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"TV","offsetgroup":"TV","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 24","LCP","France Info:"],"xaxis":"x","y":[0.053703703703703705,0.022222222222222223,0.014814814814814815],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{" ...

# %%
# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data,list_of_channels=top_channels_tv_gen,n = 3,
                               method = multiplier,height = 400,text_auto = ".1%")
fig.update_layout(yaxis_tickformat='0%',
                  title = "Podium TV -  Chaînes généralistes",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=COLOR_TV)
fig
# Out:
# <div>                            <div id="3094f6ca-325f-4b81-b017-225c0442f079" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3094f6ca-325f-4b81-b017-225c0442f079")) {                    Plotly.newPlot(                        "3094f6ca-325f-4b81-b017-225c0442f079",                        [{"alignmentgroup":"True","hovertemplate":"media=TV<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TV","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"TV","offsetgroup":"TV","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 2","RMC Story","TMC"],"xaxis":"x","y":[0.005555555555555556,0.003703703703703704,0.003703703703703704],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outl ...

# %%
# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data,list_of_channels=top_channels_radio,n = 3,
                               method = multiplier,height = 400,text_auto = ".1%")

fig.update_layout(yaxis_tickformat='0%',
                  title = "Podium Radio",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=COLOR_RADIO)
fig
# Out:
# <div>                            <div id="7e0dd501-afd1-499a-b4b6-06694196a095" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e0dd501-afd1-499a-b4b6-06694196a095")) {                    Plotly.newPlot(                        "7e0dd501-afd1-499a-b4b6-06694196a095",                        [{"alignmentgroup":"True","hovertemplate":"media=Radio<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Radio","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"Radio","offsetgroup":"Radio","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["RFI","France Culture","Nova"],"xaxis":"x","y":[0.07222222222222223,0.031481481481481485,0.02592592592592593],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"color ...

# %% [markdown]
# ## Analyse 3 - Classement complet TV et Radio

# %%
# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data,list_of_channels=top_channels_tv_info,n = 25,split="keyword",
                               method = multiplier,height = 400,text_auto = ".1%",
                                )
fig.update_layout(yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",legend_title = "",title = "Classement TV - Chaînes d'information en continu")
fig.update_traces(marker_color=COLOR_TV)
fig.show()

# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data,list_of_channels=top_channels_tv_gen,n = 25,split="keyword",
                               method = multiplier,height = 400,text_auto = ".1%",
                               )
fig.update_layout(yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",legend_title = "",title = "Classement TV -  Chaînes généralistes")
fig.update_traces(marker_color=COLOR_TV)
fig.show()

# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data,list_of_channels=top_channels_radio,n = 25,split = "keyword",
                               method = multiplier,height = 400,text_auto = ".1%",
                              )
fig.update_layout(yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",legend_title = "",title = "Classement Radio")
fig.update_traces(marker_color=COLOR_RADIO)
fig.show()
# Out:
# <div>                            <div id="8dd7b80e-8e5f-438b-884a-21b056c7ea96" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dd7b80e-8e5f-438b-884a-21b056c7ea96")) {                    Plotly.newPlot(                        "8dd7b80e-8e5f-438b-884a-21b056c7ea96",                        [{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 24","LCP","France Info:","BFMTV","CNEWS","LCI"],"xaxis":"x","y":[0.053703703703703705,0.022222222222222223,0.014814814814814815,0.009259259259259259,0.007407407407407408,0.005555555555555556],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""} ...
# <div>                            <div id="b19ad376-415e-47ae-80a8-c4a77dd9eb89" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b19ad376-415e-47ae-80a8-c4a77dd9eb89")) {                    Plotly.newPlot(                        "b19ad376-415e-47ae-80a8-c4a77dd9eb89",                        [{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 2","RMC Story","TMC","Canal+","France 5"],"xaxis":"x","y":[0.005555555555555556,0.003703703703703704,0.003703703703703704,0.001851851851851852,0.001851851851851852],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie ...
# <div>                            <div id="f7200a10-65ad-4c47-9dc8-27d824e02fdf" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7200a10-65ad-4c47-9dc8-27d824e02fdf")) {                    Plotly.newPlot(                        "f7200a10-65ad-4c47-9dc8-27d824e02fdf",                        [{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["RFI","France Culture","Nova","BFM Business Radio","France Info","Radio Classique","France Inter","Rire et Chansons","Ch\u00e9rie FM","RMC","France Musique","Fun Radio","Guadeloupe 1\u00e8re"],"xaxis":"x","y":[0.07222222222222223,0.031481481481481485,0.02592592592592593,0.022222222222222223,0.014814814814814815,0.014814814814814815,0.012962962962962964,0.007407407407407408,0.005555555555555556,0.003703703703703704,0.001851851851851852,0.001851851851851852,0.001851851851851852],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...

# %% [markdown]
# # Autres sujets écologiques

# %%
data_total = read_and_format_all_data_dump(path_folder = "../../data/cop27/0911/",path_channel_metadata=None)

data_total["channel_id"] = data_total["channel_name"] + "_" + data_total["media"]
data_total = data_total.merge(top_audiences[["channel_id","type"]],on = ["channel_id"],how = "inner")

data_total.loc[data_total["media"]=="TV","media2"] = "TV" + " - " + data_total["type"]
data_total.loc[data_total["media"]=="Radio","media2"] = "Radio"

data_total = filter_data_between_hours(data_total,"06:00","24:00")

data_total.loc[data_total["keywords"].map(lambda x : "COP27" in x),"keyword"] = "COP27"

data_total.shape
# Out:
# (596, 18)

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1

media_time = data_total.groupby(["media"]).agg({"count":"sum","channel_name":"nunique"})
media_time["n_channels"] = 25
media_time = media_time.append(pd.DataFrame(media_time.sum(axis = 0).rename("Total")).T)
media_time["media_time"] = media_time["count"] * 2
media_time["total_time"] = media_time["n_channels"] * n_days * 18 * 60
media_time["media_part"] = media_time["media_time"] / media_time["total_time"]

fig = px.bar(media_time.reset_index(),x = "index",y = "media_part",height = 400,text_auto = ".1%")
fig.update_layout(yaxis_tickformat='0%',
                  title = "Volume médiatique total sur les 50 chaînes TV et Radio",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=[COLOR_RADIO,COLOR_TV])
fig.show()
# Out:
# <div>                            <div id="185c39d2-d8cb-470c-bbf5-59898ae1f71e" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("185c39d2-d8cb-470c-bbf5-59898ae1f71e")) {                    Plotly.newPlot(                        "185c39d2-d8cb-470c-bbf5-59898ae1f71e",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>media_part=%{y}<extra></extra>","legendgroup":"","marker":{"color":["#08306b","#08519c"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.1%}","x":["Radio","TV","Total"],"xaxis":"x","y":[0.025703703703703704,0.018444444444444444,0.022074074074074072],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ti ...

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1

media_time = data_total.groupby(["media2"]).agg({"count":"sum","channel_name":"nunique"})
media_time.loc["Radio","n_channels"] = 25
media_time.loc["TV - Généraliste","n_channels"] = 19
media_time.loc["TV - Information en continu","n_channels"] = 6
media_time = media_time.append(pd.DataFrame(media_time.sum(axis = 0).rename("Total")).T)
media_time["media_time"] = media_time["count"] * 2
media_time["total_time"] = media_time["n_channels"] * n_days * 18 * 60
media_time["media_part"] = media_time["media_time"] / media_time["total_time"]

fig = px.bar(media_time.reset_index(),x = "index",y = "media_part",height = 400,text_auto = ".1%")
fig.update_layout(yaxis_tickformat='0%',
                  title = "Volume médiatique total sur les 50 chaînes TV et Radio",
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color=[COLOR_RADIO,COLOR_TV,COLOR_TV])
fig.show()
# Out:
# <div>                            <div id="0cd39795-ba2d-4229-a914-3a5a9fd9d9d2" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cd39795-ba2d-4229-a914-3a5a9fd9d9d2")) {                    Plotly.newPlot(                        "0cd39795-ba2d-4229-a914-3a5a9fd9d9d2",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>media_part=%{y}<extra></extra>","legendgroup":"","marker":{"color":["#08306b","#08519c","#08519c"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.1%}","x":["Radio","TV - G\u00e9n\u00e9raliste","TV - Information en continu","Total"],"xaxis":"x","y":[0.025703703703703704,0.006920077972709552,0.05493827160493827,0.022074074074074072],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"au ...

# %% [markdown]
# ## Analyse 3

# %%
DISCRETE_MAP = {
    "COP27":WARMING_STRIPES_SEQUENCE[2],
    "écologie":WARMING_STRIPES_SEQUENCE[0],
}

# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data_total,list_of_channels=top_channels_tv_info,n = 25,split="keyword",
                               method = multiplier,height = 500,text_auto = ".1%",
                               color_discrete_map = DISCRETE_MAP,
                              )
fig.update_layout(yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",
                  title = "Classement TV - Chaînes d'information en continu",legend_title = "")
# fig.update_traces(marker_color='#e6381b')
fig.show()

# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data_total,list_of_channels=top_channels_tv_gen,n = 25,split="keyword",
                               method = multiplier,height = 500,text_auto = ".1%",
                               color_discrete_map = DISCRETE_MAP,
                              )
fig.update_layout(yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",
                  title = "Classement TV - Chaînes généralistes",legend_title = "")
# fig.update_traces(marker_color='#e6381b')
fig.show()


# Multiplier for one channel = n_mentions * 2 min / (60 minutes * 18h * n_days)
multiplier = 2 / (1 * 60 * 18 * 1)

fig = show_mentions_by_channel(data_total,list_of_channels=top_channels_radio,n = 25,split = "keyword",
                               method = multiplier,height = 500,text_auto = ".1%",
                               color_discrete_map = DISCRETE_MAP
                              )
fig.update_layout(yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",title = "Classement Radio",legend_title = "")
# fig.update_traces(marker_color='#f49182')
fig.show()
# Out:
# <div>                            <div id="a1d25772-cb39-45d0-9ac1-0d8a6c960c1d" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1d25772-cb39-45d0-9ac1-0d8a6c960c1d")) {                    Plotly.newPlot(                        "a1d25772-cb39-45d0-9ac1-0d8a6c960c1d",                        [{"alignmentgroup":"True","hovertemplate":"keyword=\u00e9cologie<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"\u00e9cologie","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"\u00e9cologie","offsetgroup":"\u00e9cologie","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France Info:","LCP","BFMTV","CNEWS","France 24","LCI"],"xaxis":"x","y":[0.07777777777777778,0.037037037037037035,0.03333333333333333,0.031481481481481485,0.031481481481481485,0.005555555555555556],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#2171b5","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 24","LCP","France Info:","BFMTV","CNEWS","LCI"],"xaxis":"x","y":[0.053703703703703705,0.022222222222222223,0.014814814814814815,0.009259259259259259,0.007407407407407408,0.005555555555555556],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ti ...
# <div>                            <div id="0b4c899e-71ff-41e6-9845-1556daee58f7" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b4c899e-71ff-41e6-9845-1556daee58f7")) {                    Plotly.newPlot(                        "0b4c899e-71ff-41e6-9845-1556daee58f7",                        [{"alignmentgroup":"True","hovertemplate":"keyword=\u00e9cologie<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"\u00e9cologie","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"\u00e9cologie","offsetgroup":"\u00e9cologie","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 2","W9","France 5","C8","Canal+","M6","RMC Story","TMC"],"xaxis":"x","y":[0.02962962962962963,0.02777777777777778,0.022222222222222223,0.009259259259259259,0.009259259259259259,0.007407407407407408,0.005555555555555556,0.003703703703703704],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#2171b5","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["France 2","RMC Story","TMC","Canal+","France 5"],"xaxis":"x","y":[0.005555555555555556,0.003703703703703704,0.003703703703703704,0.001851851851851852,0.001851851851851852],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorba ...
# <div>                            <div id="57740e24-2e2a-49bb-bf7a-798dde5ed6e4" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57740e24-2e2a-49bb-bf7a-798dde5ed6e4")) {                    Plotly.newPlot(                        "57740e24-2e2a-49bb-bf7a-798dde5ed6e4",                        [{"alignmentgroup":"True","hovertemplate":"keyword=\u00e9cologie<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"\u00e9cologie","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"\u00e9cologie","offsetgroup":"\u00e9cologie","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["BFM Business Radio","France Info","RFI","France Inter","Nova","France Culture","Fun Radio","RTL","RTL2","Radio Classique","RMC","Ch\u00e9rie FM","Rire et Chansons","Radio FG","Skyrock","Guadeloupe 1\u00e8re","France Musique"],"xaxis":"x","y":[0.10555555555555556,0.06296296296296297,0.05185185185185186,0.03888888888888889,0.03888888888888889,0.02777777777777778,0.016666666666666666,0.014814814814814815,0.011111111111111112,0.009259259259259259,0.007407407407407408,0.007407407407407408,0.005555555555555556,0.005555555555555556,0.005555555555555556,0.005555555555555556,0.005555555555555556],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>channel_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#2171b5","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["RFI","France Culture","Nova","BFM Business Radio","Radio Classique","France Info","France Inter","Rire et Chansons"],"xaxis":"x","y":[0.07222222222222223,0.031481481481481485,0.02592592592592593,0.022222222222222223,0.014814814814814815,0.014814814814814815,0.012962962962962964,0.007407407407407408],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8 ...

# %% [markdown]
# # Analyse des sujets mentionnés

# %%
from quotaclimat.data_processing.keyword_tool import KeywordsTool

kwt = KeywordsTool(case_sensitive=False,lowercase = True)

kwt.load_from_airtable(airtable_table_name="COP27",keyword_col = "name",variants_col=["alternatives_mediatree","alternatives"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [114], line 1
# ----> 1 from quotaclimat.data_processing.keyword_tool import KeywordsTool
#       3 kwt = KeywordsTool(case_sensitive=False,lowercase = True)
#       5 kwt.load_from_airtable(airtable_table_name="COP27",keyword_col = "name",variants_col=["alternatives_mediatree","alternatives"])
#
# File ~/Documents/GitHub/dataforgoodfr/quotaclimat/notebooks/COP27/../../quotaclimat/data_processing/keyword_tool.py:10
#       8 import seaborn as sns
#       9 from dotenv import load_dotenv
# ---> 10 from flashtext import KeywordProcessor
#      11 from inflect import engine as inflect_engine
#      12 from IPython.display import clear_output, display
#
# ModuleNotFoundError: No module named 'flashtext'

# %%
counts_total = kwt.count_keywords_on_corpus(data["text"],as_melted = True)
counts_total = counts_total.query("name!='Pays'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 counts_total = kwt.count_keywords_on_corpus(data["text"],as_melted = True)
#       2 counts_total = counts_total.query("name!='Pays'")
#
# NameError: name 'kwt' is not defined

# %%
px.treemap(
    counts_total.groupby(["name","category"])["count"].sum().reset_index(),
    path = ["category","name"],
    values = "count",
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [115], line 2
#       1 px.treemap(
# ----> 2     counts_total.groupby(["name","category"])["count"].sum().reset_index(),
#       3     path = ["category","name"],
#       4     values = "count",
#       5     color_discrete_sequence = WARMING_STRIPES_SEQUENCE
#       6 )
#
# NameError: name 'counts_total' is not defined

# %%
data_dsm = data.reset_index(drop=True).loc[counts_total.query("name=='Fonds marins'")["text_id"].tolist()]

fig = show_mentions_by_channel(data_dsm,n = 25,
                               method = "minutes",height = 400,text_auto = ".1s")
fig.update_layout(
                  font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
fig.update_traces(marker_color='#e6381b')
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [116], line 1
# ----> 1 data_dsm = data.reset_index(drop=True).loc[counts_total.query("name=='Fonds marins'")["text_id"].tolist()]
#       3 fig = show_mentions_by_channel(data_dsm,n = 25,
#       4                                method = "minutes",height = 400,text_auto = ".1s")
#       5 fig.update_layout(
#       6                   font_family="Poppins",yaxis_title="% du volume médiatique",xaxis_title = "")
#
# NameError: name 'counts_total' is not defined

# %% [markdown]
# # Focus 3 jours + classement

# %%
from tqdm.auto import tqdm

data_all_days = []
for folder in tqdm(["05","06","07","08","09"]):
    
    day = f"{folder}11"

    data_total = read_and_format_all_data_dump(path_folder = f"../../data/cop27/{day}/",path_channel_metadata=None)

    data_total["channel_id"] = data_total["channel_name"] + "_" + data_total["media"]
    data_total = data_total.merge(top_audiences[["channel_id","type"]],on = ["channel_id"],how = "inner")

    data_total.loc[data_total["media"]=="TV","media2"] = "TV" + " - " + data_total["type"]
    data_total.loc[data_total["media"]=="Radio","media2"] = "Radio"

    data_total = filter_data_between_hours(data_total,"06:00","24:00").reset_index(drop = True)
    
    assert sorted(data_total["keyword"].unique()) == ["COP27","écologie"]
    
    data_total.loc[data_total["keywords"].map(lambda x : "COP27" in x),"keyword"] = "COP27"
    
    data_total["day_extract"] = day
    data_all_days.append(data_total)
    
data_all_days = pd.concat(data_all_days,axis = 0,ignore_index = True)

data_all_days["day_dt"] = data_all_days["date"].dt.date
data_all_days["day_str"] = data_all_days["day_dt"].map(str)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
method = "first" #average or first
ranking = (data_all_days
           .groupby(["channel_name","media","media2","keyword","day_dt"])["count"].sum()
           .unstack("day_dt").fillna(0.0).stack()
           .unstack("keyword").fillna(0.0).stack()
#            .unstack("channel_name").fillna(0.0).stack()
           .reset_index(drop = False)
           .rename(columns = {0:"count"})
          )

ranking["minutes"] = ranking["count"] * 2
ranking["total_time"] = 18 * 60 * 1
ranking["media_part"] = ranking["minutes"] / ranking["total_time"]

ranking["rank"] = ranking.groupby(["media2","day_dt","keyword"])["count"].transform("rank",ascending = False,method = method)
ranking["count_total"] = ranking.groupby(["channel_name","media2","day_dt"])["count"].transform("sum")
ranking["rank_total"] = ranking.groupby(["media2","day_dt","keyword"])["count_total"].transform("rank",ascending = False,method = method)
ranking["media_part_total"] = ranking["count_total"] * 2 / ranking["total_time"]
ranking["day_str"] = ranking["day_dt"].map(str)
ranking.query("media2=='TV - Généraliste' and keyword=='COP27'").head()
# Out:
#    channel_name media            media2      day_dt keyword  count  minutes  \
# 20           C8    TV  TV - Généraliste  2022-11-05   COP27    2.0      4.0
# 22           C8    TV  TV - Généraliste  2022-11-06   COP27    1.0      2.0
# 24           C8    TV  TV - Généraliste  2022-11-07   COP27    2.0      4.0
# 26           C8    TV  TV - Généraliste  2022-11-08   COP27    1.0      2.0
# 28           C8    TV  TV - Généraliste  2022-11-09   COP27    0.0      0.0
#
#     total_time  media_part  rank  count_total  rank_total  media_part_total  \
# 20        1080    0.003704   3.0          9.0         2.0          0.016667
# 22        1080    0.001852   5.0          2.0         5.0          0.003704
# 24        1080    0.003704   6.0          6.0         7.0          0.011111
# 26        1080    0.001852   6.0         10.0         5.0          0.018519
# 28        1080    0.000000   6.0          5.0         5.0          0.009259
#
#        day_str
# 20  2022-11-05
# 22  2022-11-06
# 24  2022-11-07
# 26  2022-11-08
# 28  2022-11-09

# %%
ranking_data_chart = ranking.query("media2=='TV - Généraliste' and keyword=='COP27'")

def show_ranking_chart(ranking_data,title = "",height = 500,total = False):
    
    rank_col = "rank" if not total else "rank_total"
    percent_col = "media_part" if not total else "media_part_total"
    
    
    annot_labels_data = (ranking_data
                         .loc[ranking_data["day_dt"]==ranking_data["day_dt"].max()]
                         .sort_values(rank_col,ascending = True)
                        )
    
    fig = px.line(
        ranking_data,
        x = "day_dt",
        y = rank_col,
        color = "channel_name",
        text = rank_col,
        markers = True,
        color_discrete_sequence = make_ws_palette(len(annot_labels_data)),
        category_orders = {"channel_name":annot_labels_data["channel_name"].tolist()}
    )

    # fig.update_traces(marker=dict(size=15),selector=dict(mode='markers'))
    fig.update_layout(
        xaxis_tickmode = "linear",yaxis_autorange = "reversed",
        xaxis_showgrid = False,yaxis_showgrid = False,
        xaxis_title = "Date de la COP27",
        yaxis_title = None,
        yaxis_showticklabels = False,
    )
    fig.update_traces(marker_size= 20,
                      marker = dict(line=dict(width=2)),textposition="middle center",
                      textfont_size=12,
                      textfont_color="white",
                     )



    annotations = []





    # Adding labels    
    for i,row in annot_labels_data.iterrows():
        annotations.append(dict(xref='paper', x=0.95, y=row[rank_col],
                                      xanchor='left', yanchor='middle',
                                      text=row["channel_name"] + " ("+ f'{row[percent_col]:.1%}'+")",
                                      font=dict(family='Poppins',
                                                size=12),
                                      showarrow=False))
    #     # labeling the right_side of the plot
    #     annotations.append(dict(xref='paper', x=0.95, y=y_trace[11],
    #                                   xanchor='left', yanchor='middle',
    #                                   text='{}%'.format(y_trace[11]),
    #                                   font=dict(family='Arial',
    #                                             size=16),


    fig.update_layout(
    #     width = 1000,
        margin_r = 200,
        height = height,
        annotations=annotations,
        showlegend = False,title = title,
        font_family = "Poppins"
                     )
    return fig

# %%
show_ranking_chart(
    ranking.query("media2=='TV - Généraliste' and keyword=='COP27'"),
    "Evolution du classement des chaînes TV généralistes sur la COP27",
    height = 600,
).show()

show_ranking_chart(
    ranking.query("media2=='TV - Généraliste' and keyword=='COP27'"),
    "Evolution du classement des chaînes TV généralistes sur la COP27 et l'écologie",
    height = 600,
    total = True
).show()
# Out:
# <div>                            <div id="43669192-90c6-4bbe-885f-ef17627f8a2a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43669192-90c6-4bbe-885f-ef17627f8a2a")) {                    Plotly.newPlot(                        "43669192-90c6-4bbe-885f-ef17627f8a2a",                        [{"hovertemplate":"channel_name=France 2<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France 2","line":{"color":"rgb(28,92,158)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France 2","orientation":"v","showlegend":true,"text":[2.0,1.0,1.0,1.0,1.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[2.0,1.0,1.0,1.0,1.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=RMC Story<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"RMC Story","line":{"color":"rgb(55,131,186)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"RMC Story","orientation":"v","showlegend":true,"text":[8.0,8.0,2.0,2.0,2.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[8.0,8.0,2.0,2.0,2.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=TMC<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"TMC","line":{"color":"rgb(107,172,208)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"TMC","orientation":"v","showlegend":true,"text":[10.0,10.0,3.0,4.0,3.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[10.0,10.0,3.0,4.0,3.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=Canal+<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"Canal+","line":{"color":"rgb(167,207,228)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"Canal+","orientation":"v","showlegend":true,"text":[6.0,6.0,9.0,7.0,4.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[6.0,6.0,9.0,7.0,4.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France 5<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France 5","line":{"color":"rgb(214,231,241)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France 5","orientation":"v","showlegend":true,"text":[1.0,3.0,5.0,3.0,5.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[1.0,3.0,5.0,3.0,5.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=C8<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"C8","line":{"color":"rgb(247,246,246)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"C8","orientation":"v","showlegend":true,"text":[3.0,5.0,6.0,6.0,6.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[3.0,5.0,6.0,6.0,6.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=M6<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"M6","line":{"color":"rgb(252,223,206)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"M6","orientat ...
# <div>                            <div id="7dbfcb9d-e862-497b-98f1-5750e2b9954c" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dbfcb9d-e862-497b-98f1-5750e2b9954c")) {                    Plotly.newPlot(                        "7dbfcb9d-e862-497b-98f1-5750e2b9954c",                        [{"hovertemplate":"channel_name=France 2<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France 2","line":{"color":"rgb(28,92,158)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France 2","orientation":"v","showlegend":true,"text":[3.0,2.0,2.0,1.0,1.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[3.0,2.0,2.0,1.0,1.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=W9<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"W9","line":{"color":"rgb(55,131,186)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"W9","orientation":"v","showlegend":true,"text":[11.0,11.0,11.0,11.0,2.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[11.0,11.0,11.0,11.0,2.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France 5<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France 5","line":{"color":"rgb(107,172,208)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France 5","orientation":"v","showlegend":true,"text":[1.0,1.0,3.0,2.0,3.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[1.0,1.0,3.0,2.0,3.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=Canal+<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"Canal+","line":{"color":"rgb(167,207,228)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"Canal+","orientation":"v","showlegend":true,"text":[6.0,6.0,9.0,8.0,4.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[6.0,6.0,9.0,8.0,4.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=C8<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"C8","line":{"color":"rgb(214,231,241)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"C8","orientation":"v","showlegend":true,"text":[2.0,5.0,7.0,5.0,5.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[2.0,5.0,7.0,5.0,5.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=RMC Story<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"RMC Story","line":{"color":"rgb(247,246,246)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"RMC Story","orientation":"v","showlegend":true,"text":[8.0,7.0,1.0,3.0,6.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[8.0,7.0,1.0,3.0,6.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=M6<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"M6","line":{"color":"rgb(252,223,206)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode" ...

# %%
show_ranking_chart(
    ranking.query("media2=='TV - Information en continu' and keyword=='COP27'"),
    "Evolution du classement des chaînes TV d'info en continu sur la COP27",
    height = 400,
).show()

show_ranking_chart(
    ranking.query("media2=='TV - Information en continu' and keyword=='COP27'"),
    "Evolution du classement des chaînes TV d'info en continu sur la COP27 et l'écologie",
    height = 400,
    total = True,
).show()
# Out:
# <div>                            <div id="dd442edd-abaa-442d-badb-089af3706c93" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd442edd-abaa-442d-badb-089af3706c93")) {                    Plotly.newPlot(                        "dd442edd-abaa-442d-badb-089af3706c93",                        [{"hovertemplate":"channel_name=France 24<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France 24","line":{"color":"rgb(47,120,181)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France 24","orientation":"v","showlegend":true,"text":[1.0,2.0,1.0,1.0,1.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[1.0,2.0,1.0,1.0,1.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=LCP<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"LCP","line":{"color":"rgb(135,190,218)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"LCP","orientation":"v","showlegend":true,"text":[5.0,6.0,6.0,3.0,2.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[5.0,6.0,6.0,3.0,2.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Info:<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France Info:","line":{"color":"rgb(219,233,241)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Info:","orientation":"v","showlegend":true,"text":[2.0,1.0,2.0,2.0,3.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[2.0,1.0,2.0,2.0,3.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=BFMTV<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"BFMTV","line":{"color":"rgb(251,226,212)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"BFMTV","orientation":"v","showlegend":true,"text":[3.0,3.0,3.0,6.0,4.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[3.0,3.0,3.0,6.0,4.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=CNEWS<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"CNEWS","line":{"color":"rgb(239,155,122)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"CNEWS","orientation":"v","showlegend":true,"text":[4.0,5.0,4.0,4.0,5.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[4.0,5.0,4.0,4.0,5.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=LCI<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"LCI","line":{"color":"rgb(192,53,56)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"LCI","orientation":"v","showlegend":true,"text":[6.0,4.0,5.0,5.0,6.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[6.0,4.0,5.0,5.0,6.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marke ...
# <div>                            <div id="a8069458-d1d3-414b-99c2-2ea872fb20e5" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8069458-d1d3-414b-99c2-2ea872fb20e5")) {                    Plotly.newPlot(                        "a8069458-d1d3-414b-99c2-2ea872fb20e5",                        [{"hovertemplate":"channel_name=France Info:<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France Info:","line":{"color":"rgb(47,120,181)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Info:","orientation":"v","showlegend":true,"text":[2.0,1.0,1.0,2.0,1.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[2.0,1.0,1.0,2.0,1.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France 24<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France 24","line":{"color":"rgb(135,190,218)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France 24","orientation":"v","showlegend":true,"text":[1.0,2.0,2.0,1.0,2.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[1.0,2.0,2.0,1.0,2.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=LCP<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"LCP","line":{"color":"rgb(219,233,241)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"LCP","orientation":"v","showlegend":true,"text":[4.0,6.0,6.0,3.0,3.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[4.0,6.0,6.0,3.0,3.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=BFMTV<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"BFMTV","line":{"color":"rgb(251,226,212)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"BFMTV","orientation":"v","showlegend":true,"text":[3.0,3.0,3.0,5.0,4.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[3.0,3.0,3.0,5.0,4.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=CNEWS<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"CNEWS","line":{"color":"rgb(239,155,122)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"CNEWS","orientation":"v","showlegend":true,"text":[5.0,5.0,4.0,4.0,5.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[5.0,5.0,4.0,4.0,5.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=LCI<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"LCI","line":{"color":"rgb(192,53,56)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"LCI","orientation":"v","showlegend":true,"text":[6.0,4.0,5.0,6.0,6.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[6.0,4.0,5.0,6.0,6.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"}, ...

# %%
show_ranking_chart(
    ranking.query("media2=='Radio' and keyword=='COP27'"),
    "Evolution du classement des chaînes Radio sur la COP27",
    height = 700
).show()

show_ranking_chart(
    ranking.query("media2=='Radio' and keyword=='COP27'"),
    "Evolution du classement des chaînes Radio sur la COP27 et l'écologie",
    height = 700,
    total = True,
).show()
# Out:
# <div>                            <div id="434774f3-e6aa-4b22-8459-ff58931d98a5" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("434774f3-e6aa-4b22-8459-ff58931d98a5")) {                    Plotly.newPlot(                        "434774f3-e6aa-4b22-8459-ff58931d98a5",                        [{"hovertemplate":"channel_name=RFI<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"RFI","line":{"color":"rgb(17,71,129)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"RFI","orientation":"v","showlegend":true,"text":[1.0,2.0,2.0,1.0,1.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[1.0,2.0,2.0,1.0,1.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Culture<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France Culture","line":{"color":"rgb(29,94,161)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Culture","orientation":"v","showlegend":true,"text":[6.0,7.0,6.0,4.0,2.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[6.0,7.0,6.0,4.0,2.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=Nova<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"Nova","line":{"color":"rgb(43,115,178)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"Nova","orientation":"v","showlegend":true,"text":[16.0,16.0,10.0,9.0,3.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[16.0,16.0,10.0,9.0,3.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=BFM Business Radio<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"BFM Business Radio","line":{"color":"rgb(57,134,188)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"BFM Business Radio","orientation":"v","showlegend":true,"text":[5.0,6.0,3.0,3.0,4.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[5.0,6.0,3.0,3.0,4.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Info<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France Info","line":{"color":"rgb(79,154,199)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Info","orientation":"v","showlegend":true,"text":[2.0,1.0,1.0,2.0,5.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[2.0,1.0,1.0,2.0,5.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=Radio Classique<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"Radio Classique","line":{"color":"rgb(113,176,210)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"Radio Classique","orientation":"v","showlegend":true,"text":[18.0,18.0,7.0,10.0,6.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[18.0,18.0,7.0,10.0,6.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Inter<br>day_dt=%{x}<br>rank=%{text}<extra></extra>","legendgroup":"France Inter","line":{"color":"rgb(147,197,222)","dash":"soli ...
# <div>                            <div id="9c446c7b-6f16-41a8-9742-b040b9f71b1c" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c446c7b-6f16-41a8-9742-b040b9f71b1c")) {                    Plotly.newPlot(                        "9c446c7b-6f16-41a8-9742-b040b9f71b1c",                        [{"hovertemplate":"channel_name=BFM Business Radio<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"BFM Business Radio","line":{"color":"rgb(17,71,129)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"BFM Business Radio","orientation":"v","showlegend":true,"text":[3.0,5.0,3.0,3.0,1.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[3.0,5.0,3.0,3.0,1.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=RFI<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"RFI","line":{"color":"rgb(29,94,161)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"RFI","orientation":"v","showlegend":true,"text":[1.0,2.0,2.0,2.0,2.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[1.0,2.0,2.0,2.0,2.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Info<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France Info","line":{"color":"rgb(43,115,178)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Info","orientation":"v","showlegend":true,"text":[2.0,1.0,1.0,1.0,3.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[2.0,1.0,1.0,1.0,3.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=Nova<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"Nova","line":{"color":"rgb(57,134,188)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"Nova","orientation":"v","showlegend":true,"text":[16.0,16.0,9.0,12.0,4.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[16.0,16.0,9.0,12.0,4.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Culture<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France Culture","line":{"color":"rgb(79,154,199)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Culture","orientation":"v","showlegend":true,"text":[6.0,7.0,5.0,5.0,5.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[6.0,7.0,5.0,5.0,5.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=France Inter<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"France Inter","line":{"color":"rgb(113,176,210)","dash":"solid"},"marker":{"symbol":"circle","line":{"width":2},"size":20},"mode":"lines+markers+text","name":"France Inter","orientation":"v","showlegend":true,"text":[4.0,3.0,4.0,4.0,6.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[4.0,3.0,4.0,4.0,6.0],"yaxis":"y","type":"scatter","textfont":{"color":"white","size":12},"textposition":"middle center"},{"hovertemplate":"channel_name=Radio Classique<br>day_dt=%{x}<br>rank_total=%{text}<extra></extra>","legendgroup":"Radio Classique","line":{"color ...

# %% [markdown]
# ## Evolution du volume médiatique

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
multiplier = 2 / (50 * 18 * 60)

fig = show_mentions_over_time(
    data_all_days.query("keyword=='COP27'"),
    freq = "1D",
    text_auto = ".1%",
    method = multiplier,
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# yaxis_tickformat='0%',
fig.update_layout(font_family="Poppins",
                  xaxis_tickmode = "linear",
                  xaxis_title = "Date de la COP27",
                  yaxis_title="% du volume médiatique",
                  title = "Evolution du volume médiatique sur la COP27",legend_title = "",yaxis_tickformat='0%',
                 )
fig.show()

# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
multiplier = 2 / (50 * 18 * 60)

fig = show_mentions_over_time(
    data_all_days,
    freq = "1D",
    text_auto = ".1%",
    method = multiplier,
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# yaxis_tickformat='0%',
fig.update_layout(font_family="Poppins",
                  xaxis_tickmode = "linear",
                  xaxis_title = "Date de la COP27",
                  yaxis_title="% du volume médiatique",
                  title = "Evolution du volume médiatique sur la COP27 et l'écologie",legend_title = "",yaxis_tickformat='0%',
                 )
# fig.update_traces(marker_color=WARMING_STRIPES_SEQUENCE)
fig.show()
# Out:
# <div>                            <div id="466b1149-7897-457c-b31e-14e2bbf61866" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("466b1149-7897-457c-b31e-14e2bbf61866")) {                    Plotly.newPlot(                        "466b1149-7897-457c-b31e-14e2bbf61866",                        [{"alignmentgroup":"True","hovertemplate":"date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.01274074074074074,0.024037037037037037,0.04081481481481482,0.02351851851851852,0.006925925925925926],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type" ...
# <div>                            <div id="9dbd8ad4-cd69-4d3d-a612-9891ddf7c011" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dbd8ad4-cd69-4d3d-a612-9891ddf7c011")) {                    Plotly.newPlot(                        "9dbd8ad4-cd69-4d3d-a612-9891ddf7c011",                        [{"alignmentgroup":"True","hovertemplate":"date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.024,0.04303703703703703,0.07137037037037038,0.053037037037037035,0.022074074074074072],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}] ...

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
multiplier = 2 / (50 * 18 * 60)

fig = show_mentions_over_time(
    data_all_days.query("keyword=='COP27'"),
    freq = "1D",
    split = "media2",
    text_auto = ".1%",
    method = multiplier,
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# yaxis_tickformat='0%',
fig.update_layout(font_family="Poppins",
                  xaxis_tickmode = "linear",
                  xaxis_title = "Date de la COP27",
                  yaxis_title="% du volume médiatique",
                  title = "Evolution du volume médiatique sur la COP27",legend_title = "",yaxis_tickformat='0%',
                 )
fig.show()

# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
multiplier = 2 / (50 * 18 * 60)

fig = show_mentions_over_time(
    data_all_days,
    freq = "1D",
    split = "media2",
    text_auto = ".1%",
    method = multiplier,
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# yaxis_tickformat='0%',
fig.update_layout(font_family="Poppins",
                  xaxis_tickmode = "linear",
                  xaxis_title = "Date de la COP27",
                  yaxis_title="% du volume médiatique",
                  title = "Evolution du volume médiatique sur la COP27 et l'écologie",legend_title = "",yaxis_tickformat='0%',
                 )
# fig.update_traces(marker_color=WARMING_STRIPES_SEQUENCE)
fig.show()
# Out:
# <div>                            <div id="8b7a3047-9b89-4d96-82ad-9f7d0f53262a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b7a3047-9b89-4d96-82ad-9f7d0f53262a")) {                    Plotly.newPlot(                        "8b7a3047-9b89-4d96-82ad-9f7d0f53262a",                        [{"alignmentgroup":"True","hovertemplate":"media2=Radio<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Radio","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"Radio","offsetgroup":"Radio","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.006703703703703704,0.012222222222222223,0.022703703703703705,0.01374074074074074,0.004333333333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"media2=TV - G\u00e9n\u00e9raliste<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TV - G\u00e9n\u00e9raliste","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"TV - G\u00e9n\u00e9raliste","offsetgroup":"TV - G\u00e9n\u00e9raliste","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.001074074074074074,0.001074074074074074,0.002148148148148148,0.0017407407407407406,0.0003333333333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"media2=TV - Information en continu<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TV - Information en continu","marker":{"color":"#2171b5","pattern":{"shape":""}},"name":"TV - Information en continu","offsetgroup":"TV - Information en continu","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.004962962962962963,0.01074074074074074,0.015962962962962964,0.008037037037037037,0.002259259259259259],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""}," ...
# <div>                            <div id="aa1b13d8-4f85-40af-a320-11b3d0f26871" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa1b13d8-4f85-40af-a320-11b3d0f26871")) {                    Plotly.newPlot(                        "aa1b13d8-4f85-40af-a320-11b3d0f26871",                        [{"alignmentgroup":"True","hovertemplate":"media2=Radio<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Radio","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"Radio","offsetgroup":"Radio","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.012407407407407407,0.019037037037037036,0.03551851851851852,0.029777777777777778,0.012851851851851852],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"media2=TV - G\u00e9n\u00e9raliste<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TV - G\u00e9n\u00e9raliste","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"TV - G\u00e9n\u00e9raliste","offsetgroup":"TV - G\u00e9n\u00e9raliste","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.0026296296296296298,0.004074074074074074,0.00437037037037037,0.005629629629629629,0.0026296296296296298],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"media2=TV - Information en continu<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TV - Information en continu","marker":{"color":"#2171b5","pattern":{"shape":""}},"name":"TV - Information en continu","offsetgroup":"TV - Information en continu","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.008962962962962963,0.019925925925925927,0.03148148148148148,0.01762962962962963,0.006592592592592593],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"co ...

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
multiplier = 2 / (50 * 18 * 60)

fig = show_mentions_over_time(
    data_all_days,
    freq = "1D",
    split = "keyword",
    text_auto = ".1%",
    method = multiplier,
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# yaxis_tickformat='0%',
fig.update_layout(font_family="Poppins",
                  xaxis_tickmode = "linear",
                  xaxis_title = "Date de la COP27",
                  yaxis_title="% du volume médiatique",
                  title = "Evolution du volume médiatique sur la COP27 et l'écologie",legend_title = "",yaxis_tickformat='0%',
                 )
fig.show()
# Out:
# <div>                            <div id="d735814f-a441-4328-abb8-396e0945e579" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d735814f-a441-4328-abb8-396e0945e579")) {                    Plotly.newPlot(                        "d735814f-a441-4328-abb8-396e0945e579",                        [{"alignmentgroup":"True","hovertemplate":"keyword=COP27<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"COP27","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"COP27","offsetgroup":"COP27","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.01274074074074074,0.024037037037037037,0.04081481481481482,0.02351851851851852,0.006925925925925926],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"keyword=\u00e9cologie<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"\u00e9cologie","marker":{"color":"#08519c","pattern":{"shape":""}},"name":"\u00e9cologie","offsetgroup":"\u00e9cologie","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1%}","x":["2022-11-05T00:00:00","2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00"],"xaxis":"x","y":[0.011259259259259259,0.019,0.030555555555555555,0.029518518518518517,0.015148148148148148],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d ...

# %%
# Multiplier = n_mentions * 2 min / (n_channels * 60 minutes * 18h * n_days)
n_days = 1
multiplier = 2 / (50 * 1 * 60)

fig = show_mentions_over_time(
    data_all_days,
    freq = "1H",
    split = "media",
    method = multiplier,
    color_discrete_sequence = WARMING_STRIPES_SEQUENCE
)
# yaxis_tickformat='0%',
fig.update_layout(font_family="Poppins",
                  xaxis_tickmode = "linear",
                  xaxis_title = "Date de la COP27",
                  yaxis_title="% du volume médiatique",
                  title = "Evolution du volume médiatique sur la COP27 et l'écologie",legend_title = "",yaxis_tickformat='0%',
                 )
fig.show()
# Out:
# <div>                            <div id="f7236935-45ca-434d-8ff1-6aa1c9bad739" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7236935-45ca-434d-8ff1-6aa1c9bad739")) {                    Plotly.newPlot(                        "f7236935-45ca-434d-8ff1-6aa1c9bad739",                        [{"alignmentgroup":"True","hovertemplate":"media=Radio<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Radio","marker":{"color":"#08306b","pattern":{"shape":""}},"name":"Radio","offsetgroup":"Radio","orientation":"v","showlegend":true,"textposition":"auto","x":["2022-11-05T06:00:00","2022-11-05T07:00:00","2022-11-05T08:00:00","2022-11-05T09:00:00","2022-11-05T10:00:00","2022-11-05T11:00:00","2022-11-05T12:00:00","2022-11-05T13:00:00","2022-11-05T14:00:00","2022-11-05T15:00:00","2022-11-05T16:00:00","2022-11-05T17:00:00","2022-11-05T18:00:00","2022-11-05T19:00:00","2022-11-05T20:00:00","2022-11-05T21:00:00","2022-11-05T22:00:00","2022-11-05T23:00:00","2022-11-06T06:00:00","2022-11-06T07:00:00","2022-11-06T08:00:00","2022-11-06T09:00:00","2022-11-06T10:00:00","2022-11-06T11:00:00","2022-11-06T12:00:00","2022-11-06T13:00:00","2022-11-06T14:00:00","2022-11-06T15:00:00","2022-11-06T16:00:00","2022-11-06T17:00:00","2022-11-06T18:00:00","2022-11-06T19:00:00","2022-11-06T20:00:00","2022-11-06T21:00:00","2022-11-06T22:00:00","2022-11-06T23:00:00","2022-11-07T06:00:00","2022-11-07T07:00:00","2022-11-07T08:00:00","2022-11-07T09:00:00","2022-11-07T10:00:00","2022-11-07T11:00:00","2022-11-07T12:00:00","2022-11-07T13:00:00","2022-11-07T14:00:00","2022-11-07T15:00:00","2022-11-07T16:00:00","2022-11-07T17:00:00","2022-11-07T18:00:00","2022-11-07T19:00:00","2022-11-07T20:00:00","2022-11-07T21:00:00","2022-11-07T22:00:00","2022-11-07T23:00:00","2022-11-08T06:00:00","2022-11-08T07:00:00","2022-11-08T08:00:00","2022-11-08T09:00:00","2022-11-08T10:00:00","2022-11-08T11:00:00","2022-11-08T12:00:00","2022-11-08T13:00:00","2022-11-08T14:00:00","2022-11-08T15:00:00","2022-11-08T16:00:00","2022-11-08T17:00:00","2022-11-08T18:00:00","2022-11-08T19:00:00","2022-11-08T20:00:00","2022-11-08T21:00:00","2022-11-08T22:00:00","2022-11-08T23:00:00","2022-11-09T06:00:00","2022-11-09T07:00:00","2022-11-09T08:00:00","2022-11-09T09:00:00","2022-11-09T10:00:00","2022-11-09T11:00:00","2022-11-09T12:00:00","2022-11-09T13:00:00","2022-11-09T14:00:00","2022-11-09T15:00:00","2022-11-09T16:00:00","2022-11-09T17:00:00","2022-11-09T18:00:00","2022-11-09T19:00:00","2022-11-09T20:00:00","2022-11-09T21:00:00","2022-11-09T22:00:00","2022-11-09T23:00:00"],"xaxis":"x","y":[0.012666666666666666,0.01,0.013333333333333332,0.018,0.005333333333333333,0.016666666666666666,0.024,0.01,0.007333333333333333,0.007333333333333333,0.006666666666666666,0.011333333333333332,0.026,0.017333333333333333,0.010666666666666666,0.008666666666666666,0.008,0.01,0.026666666666666665,0.029333333333333333,0.04133333333333333,0.019333333333333334,0.026,0.01,0.024666666666666667,0.030666666666666665,0.018,0.011333333333333332,0.012,0.011333333333333332,0.022,0.018666666666666665,0.014,0.008,0.008666666666666666,0.010666666666666666,0.06866666666666667,0.08066666666666666,0.06933333333333333,0.038,0.014,0.021333333333333333,0.04666666666666666,0.038,0.03133333333333333,0.02,0.03,0.019333333333333334,0.04133333333333333,0.033999999999999996,0.029333333333333333,0.011333333333333332,0.021333333333333333,0.024666666666666667,0.04133333333333333,0.056,0.05533333333333333,0.033999999999999996,0.010666666666666666,0.020666666666666667,0.032,0.026,0.03,0.018666666666666665,0.032,0.018666666666666665,0.03666666666666667,0.033999999999999996,0.015333333333333332,0.032,0.024,0.018666666666666665,0.03866666666666667,0.030666666666666665,0.038,0.014666666666666666,0.004666666666666666,0.01,0 ...

# %% [markdown]
# ## Evolution des volumes médiatiques par chaîne

# %%
ranking_chart_data = ranking.query("media2=='TV - Généraliste' and keyword=='COP27'")
rank_col = "media_part"

annot_labels_data = (ranking_chart_data
                     .loc[ ranking_chart_data["day_dt"].map(lambda x : x.day)==7]
                     .sort_values(rank_col,ascending = False)
                    )
px.colors.sequential.RdBu_r
fig = px.line(
    ranking_chart_data,
    x = "day_dt",
    y = rank_col,
    color = "channel_name",
    text = rank_col,
    markers = True,
#     color_discrete_map = "RdBu_r",
    color_discrete_sequence = make_ws_palette(len(annot_labels_data)),
    category_orders = {"channel_name":annot_labels_data["channel_name"].tolist()}
)

# fig.update_traces(marker=dict(size=15),selector=dict(mode='markers'))
fig.update_layout(
    yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",
    title = "Evolution des volumes médiatiques par chaîne TV généralistes sur la COP27",
    xaxis_tickmode = "linear",
    xaxis_title = "Date de la COP27",
    legend_title = "",
)
fig.update_layout()
fig.update_traces(
#     marker_size= 40,
    texttemplate="%{y:.1%}",
#     marker = dict(line=dict(width=2)),
    textposition="top center",
    textfont_size=12,
#     textfont_color="white"
)

fig
# Out:
# <div>                            <div id="44d13bf6-5c37-4002-b143-3c274e582a0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44d13bf6-5c37-4002-b143-3c274e582a0e")) {                    Plotly.newPlot(                        "44d13bf6-5c37-4002-b143-3c274e582a0e",                        [{"hovertemplate":"channel_name=France 2<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"France 2","line":{"color":"rgb(28,92,158)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"France 2","orientation":"v","showlegend":true,"text":[0.009259259259259259,0.025925925925925925,0.03518518518518519,0.024074074074074074,0.005555555555555556],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.009259259259259259,0.025925925925925925,0.03518518518518519,0.024074074074074074,0.005555555555555556],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=RMC Story<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"RMC Story","line":{"color":"rgb(55,131,186)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"RMC Story","orientation":"v","showlegend":true,"text":[0.0,0.0,0.02962962962962963,0.020370370370370372,0.003703703703703704],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.0,0.0,0.02962962962962963,0.020370370370370372,0.003703703703703704],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=TMC<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"TMC","line":{"color":"rgb(107,172,208)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"TMC","orientation":"v","showlegend":true,"text":[0.0,0.0,0.012962962962962963,0.014814814814814815,0.003703703703703704],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.0,0.0,0.012962962962962963,0.014814814814814815,0.003703703703703704],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=TF1<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"TF1","line":{"color":"rgb(167,207,228)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"TF1","orientation":"v","showlegend":true,"text":[0.001851851851851852,0.007407407407407408,0.011111111111111112,0.003703703703703704,0.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.001851851851851852,0.007407407407407408,0.011111111111111112,0.003703703703703704,0.0],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=France 5<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"France 5","line":{"color":"rgb(214,231,241)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"France 5","orientation":"v","showlegend":true,"text":[0.03518518518518519,0.007407407407407408,0.009259259259259259,0.018518518518518517,0.001851851851851852],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.03518518518518519,0.007407407407407408,0.009259259259259259,0.018518518518518517,0.001851851851851852],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=C8<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"C8","line":{"color":"rgb(247,246,246)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+ ...

# %%
ranking_chart_data = ranking.query("media2=='TV - Information en continu' and keyword=='COP27'")
rank_col = "media_part"

annot_labels_data = (ranking_chart_data
                     .loc[ ranking_chart_data["day_dt"].map(lambda x : x.day)==7]
                     .sort_values(rank_col,ascending = False)
                    )

fig = px.line(
    ranking_chart_data,
    x = "day_dt",
    y = rank_col,
    color = "channel_name",
    text = rank_col,
    markers = True,
    color_discrete_sequence = make_ws_palette(len(annot_labels_data)),
    category_orders = {"channel_name":annot_labels_data["channel_name"].tolist()}
)

# fig.update_traces(marker=dict(size=15),selector=dict(mode='markers'))
fig.update_layout(
    yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",
    title = "Evolution des volumes médiatiques par chaîne TV d'infos en continu sur la COP27",
    xaxis_tickmode = "linear",
    xaxis_title = "Date de la COP27",
    legend_title = "",
)
fig.update_layout()
fig.update_traces(
#     marker_size= 40,
    texttemplate="%{y:.1%}",
#     marker = dict(line=dict(width=2)),
    textposition="top center",
    textfont_size=12,
#     textfont_color="white"
)

fig
# Out:
# <div>                            <div id="07cd11a7-406f-4ee0-92c6-7cfab53f341f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07cd11a7-406f-4ee0-92c6-7cfab53f341f")) {                    Plotly.newPlot(                        "07cd11a7-406f-4ee0-92c6-7cfab53f341f",                        [{"hovertemplate":"channel_name=France 24<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"France 24","line":{"color":"rgb(47,120,181)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"France 24","orientation":"v","showlegend":true,"text":[0.18518518518518517,0.18518518518518517,0.2777777777777778,0.18518518518518517,0.053703703703703705],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.18518518518518517,0.18518518518518517,0.2777777777777778,0.18518518518518517,0.053703703703703705],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=France Info:<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"France Info:","line":{"color":"rgb(135,190,218)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"France Info:","orientation":"v","showlegend":true,"text":[0.03888888888888889,0.20185185185185187,0.26851851851851855,0.09259259259259259,0.014814814814814815],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.03888888888888889,0.20185185185185187,0.26851851851851855,0.09259259259259259,0.014814814814814815],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=BFMTV<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"BFMTV","line":{"color":"rgb(219,233,241)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"BFMTV","orientation":"v","showlegend":true,"text":[0.009259259259259259,0.07592592592592592,0.07962962962962963,0.024074074074074074,0.009259259259259259],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.009259259259259259,0.07592592592592592,0.07962962962962963,0.024074074074074074,0.009259259259259259],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=CNEWS<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"CNEWS","line":{"color":"rgb(251,226,212)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"CNEWS","orientation":"v","showlegend":true,"text":[0.007407407407407408,0.024074074074074074,0.07592592592592592,0.03518518518518519,0.007407407407407408],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.007407407407407408,0.024074074074074074,0.07592592592592592,0.03518518518518519,0.007407407407407408],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=LCI<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"LCI","line":{"color":"rgb(239,155,122)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"LCI","orientation":"v","showlegend":true,"text":[0.001851851851851852,0.05,0.06851851851851852,0.027777777777777776,0.005555555555555556],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.001851851851851852,0.05,0.06851851851851852,0.027777777777777776,0.005555555555555556],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=LCP<br>day_dt=%{x}<br>media_part=%{text}<e ...

# %%
ranking_chart_data = ranking.query("media2=='Radio' and keyword=='COP27'")
rank_col = "media_part"

annot_labels_data = (ranking_chart_data
                     .loc[ ranking_chart_data["day_dt"].map(lambda x : x.day)==7]
                     .sort_values(rank_col,ascending = False)
                    )

fig = px.line(
    ranking_chart_data,
    x = "day_dt",
    y = rank_col,
    color = "channel_name",
    text = rank_col,
    markers = True,
    color_discrete_sequence = make_ws_palette(len(annot_labels_data)),
    category_orders = {"channel_name":annot_labels_data["channel_name"].tolist()}
)

# fig.update_traces(marker=dict(size=15),selector=dict(mode='markers'))
fig.update_layout(
    yaxis_tickformat='0%',font_family="Poppins",yaxis_title="% du volume médiatique",
    title = "Evolution des volumes médiatiques par chaîne Radio sur la COP27",
    xaxis_tickmode = "linear",
    xaxis_title = "Date de la COP27",
    legend_title = "",
)
fig.update_layout()
fig.update_traces(
#     marker_size= 40,
    texttemplate="%{y:.1%}",
#     marker = dict(line=dict(width=2)),
    textposition="top center",
    textfont_size=12,
#     textfont_color="white"
)

fig
# Out:
# <div>                            <div id="4ea2e093-ed2a-4c5e-8278-2156722e359d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ea2e093-ed2a-4c5e-8278-2156722e359d")) {                    Plotly.newPlot(                        "4ea2e093-ed2a-4c5e-8278-2156722e359d",                        [{"hovertemplate":"channel_name=France Info<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"France Info","line":{"color":"rgb(17,71,129)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"France Info","orientation":"v","showlegend":true,"text":[0.10740740740740741,0.25555555555555554,0.3277777777777778,0.14444444444444443,0.014814814814814815],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.10740740740740741,0.25555555555555554,0.3277777777777778,0.14444444444444443,0.014814814814814815],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=RFI<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"RFI","line":{"color":"rgb(29,94,161)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"RFI","orientation":"v","showlegend":true,"text":[0.11296296296296296,0.10185185185185185,0.17777777777777778,0.1685185185185185,0.07222222222222222],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.11296296296296296,0.10185185185185185,0.17777777777777778,0.1685185185185185,0.07222222222222222],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=BFM Business Radio<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"BFM Business Radio","line":{"color":"rgb(43,115,178)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"BFM Business Radio","orientation":"v","showlegend":true,"text":[0.027777777777777776,0.018518518518518517,0.11481481481481481,0.08148148148148149,0.022222222222222223],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.027777777777777776,0.018518518518518517,0.11481481481481481,0.08148148148148149,0.022222222222222223],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=RTL<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"RTL","line":{"color":"rgb(57,134,188)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"RTL","orientation":"v","showlegend":true,"text":[0.03518518518518519,0.07222222222222222,0.08333333333333333,0.027777777777777776,0.0],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.03518518518518519,0.07222222222222222,0.08333333333333333,0.027777777777777776,0.0],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=France Inter<br>day_dt=%{x}<br>media_part=%{text}<extra></extra>","legendgroup":"France Inter","line":{"color":"rgb(79,154,199)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"France Inter","orientation":"v","showlegend":true,"text":[0.02962962962962963,0.06111111111111111,0.07407407407407407,0.03333333333333333,0.012962962962962963],"x":["2022-11-05","2022-11-06","2022-11-07","2022-11-08","2022-11-09"],"xaxis":"x","y":[0.02962962962962963,0.06111111111111111,0.07407407407407407,0.03333333333333333,0.012962962962962963],"yaxis":"y","type":"scatter","textfont":{"size":12},"textposition":"top center","texttemplate":"%{y:.1%}"},{"hovertemplate":"channel_name=France Culture<br>day_d ...
