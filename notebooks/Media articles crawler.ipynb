# %%
# LINE TO DELETE - Test Git Push

# %%
# Import libraries
import re
import pandas as pd
import advertools as adv

from advertools import crawl
from typing import Dict, List, Optional

# %%
# TODO
# - deduplication
# -

# %%
""" Config with various media brand info to crawl and parse """

media_config = {

    "bfmtv": {
        "sitemap_index": None,
        "sitemap_url": "https://www.bfmtv.com/sitemap_news.xml",
        "regex_section": r"^https:\/\/www\.bfmtv\.com\/(?P<section>[\/\w-]*)\/.+$",
        "type": "tv"
    },
    "lefigaro": {
        "sitemap_index": None,
        "sitemap_url": "https://www.lefigaro.fr/sitemap_news.xml",
        "regex_section": r"^https:\/\/www\.lefigaro\.fr\/(?P<section>[\/\w-]*)\/.+$",
        "type": "webpress"
    },
    "francetvinfo": {
        "sitemap_index": None,
        "sitemap_url": "https://www.francetvinfo.fr/sitemap_news.xml",
        "regex_section": r"^https:\/\/www\.francetvinfo\.fr\/(?P<section>[\/\w-]*)\/.+$",
        "type": "tv"
    },
    "lemonde": {
        "sitemap_index": None,
        "sitemap_url": "https://www.lemonde.fr/sitemap_news.xml",
        "regex_section": r"^https:\/\/www\.lemonde\.fr\/(?P<section>[\/\w-]*)\/.+$",
    },
    
    "20_minutes": {
        "sitemap_index": None,
        "sitemap_url": "https://www.20minutes.fr/sitemap-news.xml",
        "regex_section": r"^https:\/\/www\.20minutes\.fr\/(?P<section>[\/\w-]*)\/.+$",
        "type": "webpress"
    },

    "liberation": {
        "sitemap_index": None,
        "sitemap_url": "https://www.liberation.fr/arc/outboundfeeds/sitemap_news.xml?outputType=xml",
        "regex_section": r"^https:\/\/www\.liberation\.fr\/(?P<section>[\/\w-]*)\/.+$",
        "type": "webpress"
    },

    "nouvel_obs": {
        "sitemap_index": None,
        "sitemap_url": "https://www.nouvelobs.com/sitemap-articles-news.xml",
        "regex_section": r"^https:\/\/www\.nouvelobs\.com\/(?P<section>[\/\w-]*)\/.+$",
        "type": "webpress"
    },

    "le_point": {
        "sitemap_index": None,
        "sitemap_url": "https://www.lepoint.fr/sitemap-news.xml",
        "regex_section": r"^https:\/\/www\.lepoint\.fr\/(?P<section>[\/\w-]*)\/.+$",
        "type": "webpress"
    },

    "lexpress": {
        "sitemap_index": None,
        "sitemap_url": "https://www.lexpress.fr/sitemap_actu_1.xml",
        "regex_section": r"^https:\/\/www\.lexpress\.fr\/(?P<section>[\/\w-]*)\/.+$",
        "type": "webpress"
    }

}

# %%
def get_sitemap(media_config: Dict) -> pd.DataFrame:
    ''' Scrap sitemap for each media and returns df '''
    
    df = pd.DataFrame(columns=[
        'loc', 'lastmod', 'news_publication_date', 'news_title', 'publication_name', 'download_date'])
    
    for media, media_conf in media_config.items():
        
        temp_df = adv.sitemap_to_df(media_conf['sitemap_url'])
        temp_df['media'] = media
        df = pd.concat([df, temp_df], axis=0)

    return df

# %%
def clean_df(df: pd.DataFrame) -> pd.DataFrame:
    ''' Clean df from unused columns '''
    
    df = df.rename(columns={'loc':'url'})
    df = df.drop(['image_loc', 'image_caption', 'sitemap', 'sitemap_size_mb', 'news',
   'news_publication', 'news_keywords', 'image', 'news_genres', 'etag', 'sitemap_last_modified', 
    'changefreq', 'priority', 'news_access', 'publication_language', 'lastmod', 'publication_name'], axis=1)
    
    return df

# %%
def find_sections(media_config: Dict, url: str, media: str) -> List[str]:
    ''' Find and parse section with url '''
    
    clean_url_from_date = re.sub(r"\/[0-9]{2,4}\/[0-9]{2,4}\/[0-9]{2,4}", '', url)
    search_url = re.search(media_config[media]["regex_section"], clean_url_from_date)
        
    return search_url.group("section").split('/') if search_url else ["unknown"]

# %%
def get_sections(media_config: Dict, df: pd.DataFrame)-> pd.DataFrame:
    ''' Get sections and apply it to df '''
    
    df["section"] = df.apply(lambda x: find_sections(media_config, x.url, x.media), axis=1)
    
    return df

# %%
def change_datetime_format(df: pd.DataFrame) -> pd.DataFrame:
    """ Changes the date format for BQ """

    # WARNING: timezone information are deleted in this function.
    for column_name in ["news_publication_date", "download_date"]:
        df[column_name] = pd.to_datetime(df[column_name]).apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
        df[column_name] = df[column_name].apply(pd.Timestamp)
        
    return df

# %%
def run()-> pd.DataFrame:
    
    df = get_sitemap(media_config)
    df = clean_df(df)
    df = get_sections(media_config, df)
    df = change_datetime_format(df)
    
    return df

# %%
df = run()
df
# Out:
# 2022-11-20 13:58:16,106 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.bfmtv.com/sitemap_news.xml
# 2022-11-20 13:58:16,280 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lefigaro.fr/sitemap_news.xml
# 2022-11-20 13:58:16,402 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.francetvinfo.fr/sitemap_news.xml
# 2022-11-20 13:58:16,571 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lemonde.fr/sitemap_news.xml
# 2022-11-20 13:58:16,721 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.20minutes.fr/sitemap-news.xml
# 2022-11-20 13:58:16,925 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.liberation.fr/arc/outboundfeeds/sitemap_news.xml?outputType=xml
# 2022-11-20 13:58:17,172 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nouvelobs.com/sitemap-articles-news.xml
# 2022-11-20 13:58:17,405 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lepoint.fr/sitemap-news.xml
# 2022-11-20 13:58:17,636 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lexpress.fr/sitemap_actu_1.xml
#                                                    url news_publication_date  \
# 0    https://www.bfmtv.com/normandie/replay-emissio...   2022-11-20 12:53:44
# 1    https://www.bfmtv.com/tech/une-application-per...   2022-11-20 12:48:33
# 2    https://www.bfmtv.com/normandie/replay-emissio...   2022-11-20 12:48:06
# 3    https://www.bfmtv.com/police-justice/affaire-e...   2022-11-20 12:45:05
# 4    https://www.bfmtv.com/cote-d-azur/malgre-une-c...   2022-11-20 12:41:39
# ..                                                 ...                   ...
# 97   https://www.lexpress.fr/actualites/1/actualite...   2022-11-18 16:05:02
# 98   https://www.lexpress.fr/actualites/1/actualite...   2022-11-18 20:15:06
# 99   https://www.lexpress.fr/actualites/1/monde/ukr...   2022-11-20 04:45:21
# 100  https://www.lexpress.fr/actualites/1/actualite...   2022-11-18 23:10:06
# 101  https://www.lexpress.fr/actualite/monde/europe...   2022-11-19 13:39:55
#
#                                             news_title       download_date  \
# 0    Seine-Maritime: un jeune homme brûlé à 35% à L... 2022-11-20 12:58:16
# 1    Une application permet de localiser les zones ... 2022-11-20 12:58:16
# 2    Le Havre: des visites fictives inclusives pour... 2022-11-20 12:58:16
# 3    Affaire Élisa Pilarski: 3 ans après, l'enquête... 2022-11-20 12:58:16
# 4    Malgré une Coupe du monde polémique, le siège ... 2022-11-20 12:58:16
# ..                                                 ...                 ...
# 97   Les supporters privés d'alcool autour des stad... 2022-11-20 12:58:17
# 98   Mondial: nuages autour de Benzema, Ballon d'Or... 2022-11-20 12:58:17
# 99   Sunak assure Kiev du soutien britannique "jusq... 2022-11-20 12:58:17
# 100  Mondial-2022: les organisateurs font volte-fac... 2022-11-20 12:58:17
# 101  Guerre en Ukraine : comment l'armée russe a tr... 2022-11-20 12:58:17
#
#         media                                            section
# 0       bfmtv  [normandie, replay-emissions, normandie-week-end]
# 1       bfmtv                                             [tech]
# 2       bfmtv  [normandie, replay-emissions, normandie-week-end]
# 3       bfmtv                                   [police-justice]
# 4       bfmtv                                      [cote-d-azur]
# ..        ...                                                ...
# 97   lexpress                         [actualites, 1, actualite]
# 98   lexpress                         [actualites, 1, actualite]
# 99   lexpress                             [actualites, 1, monde]
# 100  lexpress                         [actualites, 1, actualite]
# 101  lexpress                         [actualite, monde, europe]
#
# [2463 rows x 6 columns]

# %%
df = run()
df
# Out:
# 2022-11-22 18:54:52,691 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.bfmtv.com/sitemap_news.xml
# 2022-11-22 18:54:53,140 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lefigaro.fr/sitemap_news.xml
# 2022-11-22 18:54:53,535 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.francetvinfo.fr/sitemap_news.xml
# 2022-11-22 18:54:54,069 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lemonde.fr/sitemap_news.xml
# 2022-11-22 18:54:54,411 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.20minutes.fr/sitemap-news.xml
# 2022-11-22 18:54:54,660 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.liberation.fr/arc/outboundfeeds/sitemap_news.xml?outputType=xml
# 2022-11-22 18:54:55,229 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nouvelobs.com/sitemap-articles-news.xml
# 2022-11-22 18:54:55,567 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lepoint.fr/sitemap-news.xml
# 2022-11-22 18:54:55,955 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lexpress.fr/sitemap_actu_1.xml
#                                                    url news_publication_date  \
# 0    https://www.bfmtv.com/tech/bons-plans/black-fr...   2022-11-22 17:53:00
# 1    https://www.bfmtv.com/var/replay-emissions/bon...   2022-11-22 17:52:17
# 2    https://www.bfmtv.com/economie/hausse-des-prix...   2022-11-22 17:49:27
# 3    https://www.bfmtv.com/sante/variole-du-singe-u...   2022-11-22 17:48:35
# 4    https://www.bfmtv.com/economie/achats-de-jouet...   2022-11-22 17:47:44
# ..                                                 ...                   ...
# 106  https://www.lexpress.fr/actualites/1/societe/v...   2022-11-21 14:15:21
# 107  https://www.lexpress.fr/actualites/1/societe/c...   2022-11-20 20:10:04
# 108  https://www.lexpress.fr/actualites/1/monde/la-...   2022-11-20 19:50:21
# 109  https://www.lexpress.fr/actualites/1/actualite...   2022-11-20 20:40:04
# 110  https://www.lexpress.fr/actualites/1/monde/la-...   2022-11-20 19:05:10
#
#                                             news_title       download_date  \
# 0    Black Friday : remise sur les AirPods Pro 2 pe... 2022-11-22 17:54:52
# 1    Toulon: les professionnels du secteur de la ju... 2022-11-22 17:54:52
# 2    Hausse des prix: le porte-parole de JouéClub n... 2022-11-22 17:54:52
# 3    Variole du singe: une étude britannique indiqu... 2022-11-22 17:54:52
# 4    Achats de jouets de Noël: "Les consommateurs o... 2022-11-22 17:54:52
# ..                                                 ...                 ...
# 106  Vins: les enchères des Hospices de Beaune à de... 2022-11-22 17:54:55
# 107  Collégienne tuée en Lot-et-Garonne: le suspect... 2022-11-22 17:54:55
# 108  La Russie et l'Ukraine s'accusent de bombardem... 2022-11-22 17:54:55
# 109  Mondial: pas de miracle pour le Qatar, dominé ... 2022-11-22 17:54:55
# 110  La Francophonie veut peser sur le règlement de... 2022-11-22 17:54:55
#
#         media                               section
# 0       bfmtv                    [tech, bons-plans]
# 1       bfmtv  [var, replay-emissions, bonsoir-var]
# 2       bfmtv                            [economie]
# 3       bfmtv                               [sante]
# 4       bfmtv                            [economie]
# ..        ...                                   ...
# 106  lexpress              [actualites, 1, societe]
# 107  lexpress              [actualites, 1, societe]
# 108  lexpress                [actualites, 1, monde]
# 109  lexpress            [actualites, 1, actualite]
# 110  lexpress                [actualites, 1, monde]
#
# [3299 rows x 6 columns]

# %%
df.groupby('media').count()
# Out:
#                url  news_publication_date  news_title  download_date  section
# media
# 20_minutes     462                    462         462            462      462
# bfmtv         1000                   1000        1000           1000     1000
# francetvinfo   361                    361         361            361      361
# le_point       252                    252         252            252      252
# lefigaro       686                    686         686            686      686
# lemonde        237                    237         237            237      237
# lexpress       111                    111         111            111      111
# liberation     100                    100         100            100      100
# nouvel_obs      90                     90          90             90       90

# %%
df.groupby('media').count()

# %%
len(df[df.news_title.str.contains("COP")])/len(df)
# Out:
# 0.009093664746892998

# %%
df[df.news_title.str.contains("COP")]
# Out:
#                                                    url news_publication_date  \
# 898  https://www.bfmtv.com/environnement/climat/man...   2022-11-21 10:59:04
# 239  https://www.lefigaro.fr/vox/societe/cop27-plut...   2022-11-21 17:09:59
# 516  https://www.lefigaro.fr/sciences/remy-roux-cer...   2022-11-20 20:35:42
# 559  https://www.lefigaro.fr/flash-actu/cop27-encor...   2022-11-21 11:41:08
# 589  https://www.lefigaro.fr/sciences/cop27-un-acco...   2022-11-19 14:12:00
# 596  https://www.lefigaro.fr/international/cop27-l-...   2022-11-20 20:05:33
# 213  https://www.francetvinfo.fr/monde/environnemen...   2022-11-21 19:10:16
# 297  https://www.francetvinfo.fr/replay-radio/les-i...   2022-11-21 10:42:05
# 342  https://www.francetvinfo.fr/monde/environnemen...   2022-11-20 22:29:33
# 343  https://www.francetvinfo.fr/replay-radio/les-i...   2022-11-20 22:10:06
# 350  https://www.francetvinfo.fr/monde/environnemen...   2022-11-20 21:38:31
# 356  https://www.francetvinfo.fr/monde/environnemen...   2022-11-20 21:04:25
# 128  https://www.lemonde.fr/planete/article/2022/11...   2022-11-21 19:30:14
# 177  https://www.lemonde.fr/planete/article/2022/11...   2022-11-21 11:17:15
# 186  https://www.lemonde.fr/idees/article/2022/11/2...   2022-11-21 10:00:04
# 213  https://www.lemonde.fr/planete/article/2022/11...   2022-11-21 15:46:27
# 233  https://www.lemonde.fr/les-decodeurs/article/2...   2022-11-21 06:49:16
# 19   https://www.20minutes.fr/planete/4011200-20221...   2022-11-22 18:04:07
# 339  https://www.20minutes.fr/planete/4010796-20221...   2022-11-21 13:23:37
# 451  https://www.20minutes.fr/diaporama/diaporama-1...   2022-11-22 16:01:37
# 47   https://www.liberation.fr/idees-et-debats/opin...   2022-11-22 09:42:01
# 74   https://www.nouvelobs.com/ecologie/20221120.OB...   2022-11-20 00:00:00
# 87   https://www.nouvelobs.com/ecologie/20221120.OB...   2022-11-20 00:00:00
# 71   https://www.lepoint.fr/postillon/cop27-l-ere-d...   2022-11-22 10:30:00
# 117  https://www.lepoint.fr/monde/la-cop-19-au-seco...   2022-11-22 01:37:00
# 186  https://www.lepoint.fr/politique/emmanuel-berr...   2022-11-21 12:17:00
# 195  https://www.lepoint.fr/environnement/dette-cli...   2022-11-21 07:00:00
# 196  https://www.lepoint.fr/video/dette-climatique-...   2022-11-21 11:03:00
# 47   https://www.lexpress.fr/actualites/1/monde/la-...   2022-11-22 02:55:03
# 65   https://www.lexpress.fr/actualites/1/actualite...   2022-11-21 17:05:04
#
#                                             news_title       download_date  \
# 898  "Manque d'ambition" et "déception": quel bilan... 2022-11-22 17:54:52
# 239  COP27 : «La décroissance n'est pas une option,... 2022-11-22 17:54:53
# 516  Rémy Rioux: «Certains résultats de la COP27 so... 2022-11-22 17:54:53
# 559  COP27 : «encore un long chemin» après l'accord... 2022-11-22 17:54:53
# 589  Un succès en demi-teinte pour la COP27 qui min... 2022-11-22 17:54:53
# 596  COP27: l’agriculture, le parent pauvre des nég... 2022-11-22 17:54:53
# 213  COP27 : pourquoi l'accord final ne mentionne-t... 2022-11-22 17:54:53
# 297  L'aide du gouvernement aux entreprises face à ... 2022-11-22 17:54:53
# 342    COP 27 : une édition décevante et sans ambition 2022-11-22 17:54:53
# 343  Mondial au Qatar c'est parti, Benzema forfait,... 2022-11-22 17:54:53
# 350  COP27 : trois questions sur le fonds sur les "... 2022-11-22 17:54:53
# 356  Fin de la COP27 : "Le résultat est mitigé", re... 2022-11-22 17:54:53
# 128  A la COP27, malgré de petites avancées, la bio... 2022-11-22 17:54:54
# 177  Un bilan diplomatique mitigé pour l’Egypte, pa... 2022-11-22 17:54:54
# 186               La COP27, entre espoirs et désespoir 2022-11-22 17:54:54
# 213  COP27 : « La mise en œuvre du fonds sur les pe... 2022-11-22 17:54:54
# 233  Clôture de la COP27, coup d’envoi du Mondial 2... 2022-11-22 17:54:54
# 19   COP27 : Quel est ce nouveau fonds sur les « pe... 2022-11-22 17:54:54
# 339  COP27 : « Accord trouvé » sur le fonds dédié à... 2022-11-22 17:54:54
# 451  En images : Lula propose d'organiser la COP en... 2022-11-22 17:54:54
# 47   LR débat, Trump rempile, la COP écope… Coco cr... 2022-11-22 17:54:54
# 74   Après une COP27 au bilan contrasté, Macron veu... 2022-11-22 17:54:55
# 87   Accord sur les dégâts climatiques, mais pas d’... 2022-11-22 17:54:55
# 71          COP27 : l’ère de l’« équité climatique » ? 2022-11-22 17:54:55
# 117  La COP-19 au secours des tortues d'eau douce e... 2022-11-22 17:54:55
# 186       L’UE rentre (presque) bredouille de la COP27 2022-11-22 17:54:55
# 195  Dette climatique, 1,5 °C, méthane : ce qu’il f... 2022-11-22 17:54:55
# 196  Dette climatique, 1,5 °C, méthane : ce qu'il f... 2022-11-22 17:54:55
# 47   La COP-19 au secours des tortues d'eau douce e... 2022-11-22 17:54:55
# 65   COP27: "encore un long chemin" après l'accord ... 2022-11-22 17:54:55
#
#             media                                      section
# 898         bfmtv                      [environnement, climat]
# 239      lefigaro                               [vox, societe]
# 516      lefigaro                                   [sciences]
# 559      lefigaro                                 [flash-actu]
# 589      lefigaro                                   [sciences]
# 596      lefigaro                              [international]
# 213  francetvinfo                  [monde, environnement, cop]
# 297  francetvinfo        [replay-radio, les-informes-du-matin]
# 342  francetvinfo                  [monde, environnement, cop]
# 343  francetvinfo  [replay-radio, les-informes-de-france-info]
# 350  francetvinfo                  [monde, environnement, cop]
# 356  francetvinfo                  [monde, environnement, cop]
# 128       lemonde                           [planete, article]
# 177       lemonde                           [planete, article]
# 186       lemonde                             [idees, article]
# 213       lemonde                           [planete, article]
# 233       lemonde                     [les-decodeurs, article]
# 19     20_minutes                                    [planete]
# 339    20_minutes                                    [planete]
# 451    20_minutes                                  [diaporama]
# 47     liberation                  [idees-et-debats, opinions]
# 74     nouvel_obs                                   [ecologie]
# 87     nouvel_obs                                   [ecologie]
# 71       le_point                                  [postillon]
# 117      le_point                                      [monde]
# 186      le_point               [politique, emmanuel-berretta]
# 195      le_point                              [environnement]
# 196      le_point                                      [video]
# 47       lexpress                       [actualites, 1, monde]
# 65       lexpress                   [actualites, 1, actualite]

# %%
LANDING_PATH = 'data_public/media=%s/'

# %%
def query_one_sitemap_and_transform(media:str, media_conf: Dict)-> pd.DataFrame:
    """Query a site map url from media_conf and tranform it as pd.DataFrame

    Args:
        media_conf (Dict): from MEDIA_CONF

    Returns:
        pd.DataFrame
    """
    temp_df = adv.sitemap_to_df(media_conf['sitemap_url'])
    temp_df.rename(columns={'loc':'url'}, inplace=True)
    temp_df['media'] = media
    df = get_sections(media_conf, temp_df)
    df = change_datetime_format(df)
    return df

def sanity_check(df:pd.DataFrame):
    """ Checks if the data is correct"""
    # TODO pandera?

# TODO slack login

def write_df(df: pd.DataFrame, media: str, media_conf: Dict):
    """ Write de extracted dataframe to standardized path"""
    download_date = datetime.datetime.today()
    # TODO make dir 
    df.to_csv('/data_public/sitemap_dumps/media_type=%s/media=%s/year=%s/month=%y/day=%s'%(media_conf['type'], media, download_date.year, download_date.month, download_date.day))

def run():
    for media, media_conf in media_config.items():
        try:
            df = query_one_sitemap_and_transform(media, media_conf)
            write_df(df)
        except Exception as e:
            print(e)
            # TODO proper logging
            continue

# %%
download_date = datetime.today()

# %%
download_date.month
# Out:
# 11

# %%
year/month/day

# %%
from datetime import datetime

# %%
datetime.today().strftime('%Y%m%d_%H:%m')
# Out:
# '20221123_08:11'

# %%
media_conf
# Out:
# {'sitemap_index': None,
#  'sitemap_url': 'https://www.lexpress.fr/sitemap_actu_1.xml',
#  'regex_section': '^https:\\/\\/www\\.lexpress\\.fr\\/(?P<section>[\\/\\w-]*)\\/.+$',
#  'type': 'webpress'}

# %%
    break
# Out:
# 2022-11-23 08:58:35,389 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.bfmtv.com/sitemap_news.xml
# 'bfmtv'
# 2022-11-23 08:58:35,690 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lefigaro.fr/sitemap_news.xml
# 'lefigaro'
# 2022-11-23 08:58:36,004 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.francetvinfo.fr/sitemap_news.xml
# 2022-11-23 08:58:36,172 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lemonde.fr/sitemap_news.xml
# 'francetvinfo'
# 'lemonde'
# 2022-11-23 08:58:36,392 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.20minutes.fr/sitemap-news.xml
# 2022-11-23 08:58:36,516 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.liberation.fr/arc/outboundfeeds/sitemap_news.xml?outputType=xml
# '20_minutes'
# 'liberation'
# 2022-11-23 08:58:36,629 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nouvelobs.com/sitemap-articles-news.xml
# 'nouvel_obs'
# 2022-11-23 08:58:36,913 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lepoint.fr/sitemap-news.xml
# 'le_point'
# 2022-11-23 08:58:37,263 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.lexpress.fr/sitemap_actu_1.xml
# 'lexpress'

# %%
.news_publication_date.min()

# %%
temp_df
# Out:
#                                                    loc publication_name  \
# 0    https://www.bfmtv.com/marseille/replay-emissio...            BFMTV
# 1    https://www.bfmtv.com/cote-d-azur/replay-emiss...            BFMTV
# 2    https://www.bfmtv.com/international/asie/russi...            BFMTV
# 3    https://www.bfmtv.com/international/europe/xav...            BFMTV
# 4    https://www.bfmtv.com/marseille/replay-emissio...            BFMTV
# ..                                                 ...              ...
# 995  https://www.bfmtv.com/cote-d-azur/replay-emiss...            BFMTV
# 996  https://www.bfmtv.com/marseille/replay-emissio...            BFMTV
# 997  https://www.bfmtv.com/alsace/replay-emissions/...            BFMTV
# 998  https://www.bfmtv.com/international/asie/russi...            BFMTV
# 999  https://www.bfmtv.com/normandie/replay-emissio...            BFMTV
#
#     publication_language     news_publication_date  \
# 0                     fr  2022-11-23T07:35:07.000Z
# 1                     fr  2022-11-23T07:33:51.000Z
# 2                     fr  2022-11-23T07:33:00.000Z
# 3                     fr  2022-11-23T07:32:08.000Z
# 4                     fr  2022-11-23T07:31:57.000Z
# ..                   ...                       ...
# 995                   fr  2022-11-21T16:16:54.000Z
# 996                   fr  2022-11-21T16:15:55.000Z
# 997                   fr  2022-11-21T16:15:34.000Z
# 998                   fr  2022-11-21T16:15:15.000Z
# 999                   fr  2022-11-21T16:15:07.000Z
#
#                                             news_title  \
# 0    Coran dans un car Aix-Marseille: le chauffeur ...
# 1                    Retour sur l'affaire Magne-Ciotti
# 2    7 MINUTES POUR COMPRENDRE - L'Ukraine peut-ell...
# 3    Xavier Bettel: "Être homosexuel, d'origine jui...
# 4        Provence: attention aux santons made in China
# ..                                                 ...
# 995  Procès de l'attentat de Nice: le vendeur de la...
# 996           Marseille: une isolation éco-responsable
# 997  Alsace: le ministre chargé du commerce extérie...
# 998  Kherson: pour Vera Ageeva, les actes de tortur...
# 999      Cherbourg: sauvetage d'un homme de 83 ans mer
#
#                                              image_loc  \
# 0    https://images.bfmtv.com/SN4KZ0KS9eJ_qcRwGsSrm...
# 1    https://images.bfmtv.com/VuZoru05fV7-w6z44N-l8...
# 2    https://images.bfmtv.com/N-IeCBUHVcd1ROzCfxbEB...
# 3    https://images.bfmtv.com/0KPgL3RlLMhqJsjMaaGS-...
# 4    https://images.bfmtv.com/yEeA-1fUAVu6_jdZG8pNx...
# ..                                                 ...
# 995  https://images.bfmtv.com/ihissT63EFkqn-1OXpUpI...
# 996  https://images.bfmtv.com/2QXdf8C0W2kItpCOLuaZA...
# 997  https://images.bfmtv.com/VPgSL4eQ9d0vPdEob6uB3...
# 998  https://images.bfmtv.com/qPdu_UKVjYK-nR5WWT-rV...
# 999  https://images.bfmtv.com/NhJw5XPngkx1A9iB3W1mf...
#
#                                          image_caption  \
# 0    Coran dans un car Aix-Marseille: le chauffeur ...
# 1                    Retour sur l'affaire Magne-Ciotti
# 2    7 MINUTES POUR COMPRENDRE - L'Ukraine peut-ell...
# 3    Xavier Bettel: "Être homosexuel, d'origine jui...
# 4        Provence: attention aux santons made in China
# ..                                                 ...
# 995  Procès de l'attentat de Nice: le vendeur de la...
# 996           Marseille: une isolation éco-responsable
# 997  Alsace: le ministre chargé du commerce extérie...
# 998  Kherson: pour Vera Ageeva, les actes de tortur...
# 999      Cherbourg: sauvetage d'un homme de 83 ans mer
#
#                                     sitemap  sitemap_size_mb  \
# 0    https://www.bfmtv.com/sitemap_news.xml         0.746476
# 1    https://www.bfmtv.com/sitemap_news.xml         0.746476
# 2    https://www.bfmtv.com/sitemap_news.xml         0.746476
# 3    https://www.bfmtv.com/sitemap_news.xml         0.746476
# 4    https://www.bfmtv.com/sitemap_news.xml         0.746476
# ..                                      ...              ...
# 995  https://www.bfmtv.com/sitemap_news.xml         0.746476
# 996  https://www.bfmtv.com/sitemap_news.xml         0.746476
# 997  https://www.bfmtv.com/sitemap_news.xml         0.746476
# 998  https://www.bfmtv.com/sitemap_news.xml         0.746476
# 999  https://www.bfmtv.com/sitemap_news.xml         0.746476
#
#                        download_date  media
# 0   2022-11-23 07:37:04.531795+00:00  bfmtv
# 1   2022-11-23 07:37:04.531795+00:00  bfmtv
# 2   2022-11-23 07:37:04.531795+00:00  bfmtv
# 3   2022-11-23 07:37:04.531795+00:00  bfmtv
# 4   2022-11-23 07:37:04.531795+00:00  bfmtv
# ..                               ...    ...
# 995 2022-11-23 07:37:04.531795+00:00  bfmtv
# 996 2022-11-23 07:37:04.531795+00:00  bfmtv
# 997 2022-11-23 07:37:04.531795+00:00  bfmtv
# 998 2022-11-23 07:37:04.531795+00:00  bfmtv
# 999 2022-11-23 07:37:04.531795+00:00  bfmtv
#
# [1000 rows x 11 columns]
