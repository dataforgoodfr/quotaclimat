# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

if not os.getcwd().endswith("/quotaclimat"):
    os.chdir("../../../../..")

repo_root_path = os.path.abspath(os.path.dirname(os.getcwd()))
if repo_root_path not in sys.path:
    sys.path.append(repo_root_path)
repo_root_path
# Out:
# '/root/Workspace'

# %%
from quotaclimat.data_ingestion.advertising.s01_detection.tools.mediatree import (
    MediatreeAPI,
)

from datetime import datetime

api = MediatreeAPI()

# %%
audio_file_path = await api.download_export(
    "tf1",
    datetime(2026, 4, 4, 2, 0),
    datetime(2026, 4, 4, 2, 10),
    "mp3",
)
